# %%
import numpy as np

from bayes_window import model_comparison, BayesWindow
from bayes_window.generative_models import generate_fake_lfp

# %%
df, df_monster, index_cols, firing_rates = generate_fake_lfp(n_trials=70, mouse_response_slope=10)

BayesWindow(df, y='Power', treatment='stim', group='mouse', detail='i_trial').chart_data_box_detail.display()
BayesWindow(df, y='Log power', treatment='stim', group='mouse', detail='i_trial').chart_data_box_detail.display()
# Out:
# alt.LayerChart(...)
# alt.LayerChart(...)

# %%
# NBVAL_SKIP
# Note: Only works with single ys and single true_slopes
res = model_comparison.run_conditions(true_slopes=np.hstack([np.zeros(15),
                                                             np.tile(10, 15)]),
                                      #                                                              np.tile(np.linspace(20, 40, 3), 15)]),
                                      n_trials=np.linspace(10, 70, 5).astype(int),
                                      #                                       trial_baseline_randomness=np.linspace(.2, 11, 3),
                                      ys=('Power',),
                                      parallel=True)
# Out:
#   0%|                                                                                                                                                     | 0/450 [00:00<?, ?it/s]
#   3%|███▋                                                                                                                                        | 12/450 [00:00<00:10, 42.85it/s]
# 0it [00:00, ?it/s]
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2200: ConvergenceWarning: Retrying MixedLM optimization with lbfgs
#   warnings.warn(
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# 2it [00:00,  8.54it/s]2021-11-25 01:58:22.548188: E external/org_tensorflow/tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_COMPAT_NOT_SUPPORTED_ON_DEVICE: forward compatibility was attempted on non supported HW
# 2021-11-25 01:58:22.548457: E external/org_tensorflow/tensorflow/stream_executor/cuda/cuda_diagnostics.cc:313] kernel version 450.142.0 does not match DSO version 450.156.0 -- cannot find working devices in this configuration
# 2it [00:00,  9.38it/s]2021-11-25 01:58:22.627343: E external/org_tensorflow/tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_COMPAT_NOT_SUPPORTED_ON_DEVICE: forward compatibility was attempted on non supported HW
# 2021-11-25 01:58:22.627599: E external/org_tensorflow/tensorflow/stream_executor/cuda/cuda_diagnostics.cc:313] kernel version 450.142.0 does not match DSO version 450.156.0 -- cannot find working devices in this configuration
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2200: ConvergenceWarning: Retrying MixedLM optimization with lbfgs
#   warnings.warn(
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2200: ConvergenceWarning: Retrying MixedLM optimization with cg
#   warnings.warn(
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 0.159058
#   warnings.warn(msg, ConvergenceWarning)
# 2it [00:00,  6.30it/s]
# 2021-11-25 01:58:22.714433: E external/org_tensorflow/tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_COMPAT_NOT_SUPPORTED_ON_DEVICE: forward compatibility was attempted on non supported HW
# 2021-11-25 01:58:22.714726: E external/org_tensorflow/tensorflow/stream_executor/cuda/cuda_diagnostics.cc:313] kernel version 450.142.0 does not match DSO version 450.156.0 -- cannot find working devices in this configuration
# 0it [00:00, ?it/s]
# 2it [00:00,  9.87it/s]2021-11-25 01:58:24.899235: E external/org_tensorflow/tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_COMPAT_NOT_SUPPORTED_ON_DEVICE: forward compatibility was attempted on non supported HW
# 2021-11-25 01:58:24.899662: E external/org_tensorflow/tensorflow/stream_executor/cuda/cuda_diagnostics.cc:313] kernel version 450.142.0 does not match DSO version 450.156.0 -- cannot find working devices in this configuration
# 0it [00:00, ?it/s]/home/m/env_jb1/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2200: ConvergenceWarning: Retrying MixedLM optimization with lbfgs
#   warnings.warn(
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2200: ConvergenceWarning: Retrying MixedLM optimization with cg
#   warnings.warn(
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 0.921753
#   warnings.warn(msg, ConvergenceWarning)
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# 2it [00:00,  4.68it/s]2021-11-25 01:58:24.995450: E external/org_tensorflow/tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_COMPAT_NOT_SUPPORTED_ON_DEVICE: forward compatibility was attempted on non supported HW
# 2021-11-25 01:58:24.995708: E external/org_tensorflow/tensorflow/stream_executor/cuda/cuda_diagnostics.cc:313] kernel version 450.142.0 does not match DSO version 450.156.0 -- cannot find working devices in this configuration
# 2it [00:00, 11.52it/s]2021-11-25 01:58:25.118997: E external/org_tensorflow/tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_COMPAT_NOT_SUPPORTED_ON_DEVICE: forward compatibility was attempted on non supported HW
# 2021-11-25 01:58:25.119461: E external/org_tensorflow/tensorflow/stream_executor/cuda/cuda_diagnostics.cc:313] kernel version 450.142.0 does not match DSO version 450.156.0 -- cannot find working devices in this configuration
# 0it [00:00, ?it/s]
# 2it [00:00, 11.31it/s]2021-11-25 01:58:27.118840: E external/org_tensorflow/tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_COMPAT_NOT_SUPPORTED_ON_DEVICE: forward compatibility was attempted on non supported HW
# 2021-11-25 01:58:27.119215: E external/org_tensorflow/tensorflow/stream_executor/cuda/cuda_diagnostics.cc:313] kernel version 450.142.0 does not match DSO version 450.156.0 -- cannot find working devices in this configuration
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2200: ConvergenceWarning: Retrying MixedLM optimization with lbfgs
#   warnings.warn(
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2200: ConvergenceWarning: Retrying MixedLM optimization with cg
#   warnings.warn(
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 3.922139
#   warnings.warn(msg, ConvergenceWarning)
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# 2it [00:00,  3.32it/s]2021-11-25 01:58:27.440827: E external/org_tensorflow/tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_COMPAT_NOT_SUPPORTED_ON_DEVICE: forward compatibility was attempted on non supported HW
# 2021-11-25 01:58:27.441177: E external/org_tensorflow/tensorflow/stream_executor/cuda/cuda_diagnostics.cc:313] kernel version 450.142.0 does not match DSO version 450.156.0 -- cannot find working devices in this configuration
# 0it [00:00, ?it/s]
# 2it [00:00, 14.04it/s]2021-11-25 01:58:27.725084: E external/org_tensorflow/tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_COMPAT_NOT_SUPPORTED_ON_DEVICE: forward compatibility was attempted on non supported HW
# 2021-11-25 01:58:27.725293: E external/org_tensorflow/tensorflow/stream_executor/cuda/cuda_diagnostics.cc:313] kernel version 450.142.0 does not match DSO version 450.156.0 -- cannot find working devices in this configuration
# 0it [00:00, ?it/s]
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2200: ConvergenceWarning: Retrying MixedLM optimization with lbfgs
#   warnings.warn(
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# 2it [00:00,  8.46it/s]2021-11-25 01:58:29.035280: E external/org_tensorflow/tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_COMPAT_NOT_SUPPORTED_ON_DEVICE: forward compatibility was attempted on non supported HW
# 2021-11-25 01:58:29.035591: E external/org_tensorflow/tensorflow/stream_executor/cuda/cuda_diagnostics.cc:313] kernel version 450.142.0 does not match DSO version 450.156.0 -- cannot find working devices in this configuration
# 0it [00:00, ?it/s]
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2200: ConvergenceWarning: Retrying MixedLM optimization with lbfgs
#   warnings.warn(
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# 2it [00:00,  9.18it/s]2021-11-25 01:58:29.713684: E external/org_tensorflow/tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_COMPAT_NOT_SUPPORTED_ON_DEVICE: forward compatibility was attempted on non supported HW
# 2021-11-25 01:58:29.714105: E external/org_tensorflow/tensorflow/stream_executor/cuda/cuda_diagnostics.cc:313] kernel version 450.142.0 does not match DSO version 450.156.0 -- cannot find working devices in this configuration
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2200: ConvergenceWarning: Retrying MixedLM optimization with lbfgs
#   warnings.warn(
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# 2it [00:00,  8.76it/s]2021-11-25 01:58:29.773730: E external/org_tensorflow/tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_COMPAT_NOT_SUPPORTED_ON_DEVICE: forward compatibility was attempted on non supported HW
# 2021-11-25 01:58:29.774047: E external/org_tensorflow/tensorflow/stream_executor/cuda/cuda_diagnostics.cc:313] kernel version 450.142.0 does not match DSO version 450.156.0 -- cannot find working devices in this configuration
# 3it [00:13,  5.53s/it]
# 3it [00:13,  5.67s/it]
#   3%|███▋                                                                                                                                        | 12/450 [00:19<00:10, 42.85it/s]
# 3it [00:15,  6.52s/it]
# 3it [00:16,  6.64s/it]
# 3it [00:14,  6.17s/it]
#   5%|███████▍                                                                                                                                    | 24/450 [00:25<08:56,  1.26s/it]
# 4it [00:21,  5.47s/it]
# 4it [00:22,  5.55s/it]
# 2it [00:20, 11.52it/s]
# 3it [00:17,  7.33s/it]
# 2it [00:20, 11.31it/s]
# 2it [00:20, 14.04it/s]
# 4it [00:22,  5.57s/it]
# 4it [00:23,  5.83s/it]
# Power~stim
#              sum_sq   df     F  PR(>F)
# stim        663.29  1.0  0.07     0.8
# Residual  58087.88  6.0   NaN     NaN
# Using formula Power ~  C(stim, Treatment) + (1 | mouse)
#                            Coef. Std.Err.      z  P>|z|    [0.025   0.975]
# Intercept                  8.344   55.288  0.151  0.880  -100.017  116.706
# C(stim, Treatment)[T.1]   18.211   41.726  0.436  0.663   -63.570   99.993
# 1 | mouse                 78.433   22.897  3.425  0.001    33.555  123.311
# Group Var                356.096    5.638
# 4it [00:26,  6.61s/it]
# 4it [00:23,  5.90s/it]
# 0it [00:00, ?it/s]
# Power~stim
#               sum_sq   df     F  PR(>F)
# stim       11997.10  1.0  0.45    0.53
# Residual  161430.02  6.0   NaN     NaN
# Using formula Power ~  C(stim, Treatment) + (1 | mouse)
#                            Coef. Std.Err.       z  P>|z|    [0.025   0.975]
# Intercept                -50.463  133.936  -0.377  0.706  -312.973  212.047
# C(stim, Treatment)[T.1]   77.450  106.957   0.724  0.469  -132.182  287.082
# 1 | mouse                126.077   54.916   2.296  0.022    18.443  233.711
# Group Var                623.344
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2200: ConvergenceWarning: Retrying MixedLM optimization with lbfgs
#   warnings.warn(
# 2it [00:00,  8.83it/s]
# Power~stim
#              sum_sq   df     F  PR(>F)
# stim       1366.10  1.0  0.18    0.69
# Residual  46717.02  6.0   NaN     NaN
# Using formula Power ~  C(stim, Treatment) + (1 | mouse)
#                             Coef. Std.Err.       z  P>|z|    [0.025   0.975]
# Intercept                 135.302  100.449   1.347  0.178   -61.573  332.178
# C(stim, Treatment)[T.1]   -26.135   44.637  -0.586  0.558  -113.623   61.352
# 1 | mouse                  34.741   43.799   0.793  0.428   -51.104  120.585
# Group Var                5680.957   24.442
# 2it [00:00, 14.66it/s]
# 0it [00:00, ?it/s]
# Power~stim
#               sum_sq   df     F  PR(>F)
# stim       51644.51  1.0  2.12     0.2
# Residual  145997.72  6.0   NaN     NaN
# Using formula Power ~  C(stim, Treatment) + (1 | mouse)
#                             Coef. Std.Err.      z  P>|z|    [0.025   0.975]
# Intercept                  17.691  174.520  0.101  0.919  -324.362  359.743
# C(stim, Treatment)[T.1]   160.693  113.824  1.412  0.158   -62.398  383.785
# 1 | mouse                  51.658   73.781  0.700  0.484   -92.950  196.266
# Group Var                8818.562   43.342
# 2it [00:00,  9.17it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# Power~stim
#              sum_sq   df     F  PR(>F)
# stim       3473.42  1.0  0.78    0.41
# Residual  26663.39  6.0   NaN     NaN
# Using formula Power ~  C(stim, Treatment) + (1 | mouse)
#                            Coef. Std.Err.       z  P>|z|    [0.025   0.975]
# Intercept                 86.021   41.787   2.059  0.040     4.120  167.922
# C(stim, Treatment)[T.1]  -41.674   34.119  -1.221  0.222  -108.546   25.198
# 1 | mouse                 43.335   17.059   2.540  0.011     9.899   76.771
# Group Var                  0.004
# n(Divergences) = 1
# Power~stim
#               sum_sq   df     F  PR(>F)
# stim       67186.38  1.0  0.46    0.52
# Residual  868672.84  6.0   NaN     NaN
# Using formula Power ~  C(stim, Treatment) + (1 | mouse)
#                             Coef. Std.Err.       z  P>|z|    [0.025   0.975]
# Intercept                -112.021  313.655  -0.357  0.721  -726.773  502.730
# C(stim, Treatment)[T.1]   183.284  255.713   0.717  0.474  -317.903  684.472
# 1 | mouse                 158.729  128.087   1.239  0.215   -92.317  409.776
# Group Var                 236.626   91.450
# 2it [00:00,  6.16it/s]
# 2it [00:00, 14.49it/s]
# Power~stim
#              sum_sq   df     F  PR(>F)
# stim       1049.92  1.0  0.12    0.74
# Residual  54013.62  6.0   NaN     NaN
# Using formula Power ~  C(stim, Treatment) + (1 | mouse)
#                            Coef. Std.Err.       z  P>|z|    [0.025   0.975]
# Intercept                209.396   79.407   2.637  0.008    53.760  365.032
# C(stim, Treatment)[T.1]   22.912   64.621   0.355  0.723  -103.743  149.567
# 1 | mouse                -17.287   32.439  -0.533  0.594   -80.867   46.293
# Group Var                 33.346
# Power~stim
#              sum_sq   df     F  PR(>F)
# stim       1134.57  1.0  0.32    0.59
# Residual  21193.87  6.0   NaN     NaN
# Using formula Power ~  C(stim, Treatment) + (1 | mouse)
#                             Coef. Std.Err.      z  P>|z|   [0.025   0.975]
# Intercept                  74.569   54.108  1.378  0.168  -31.481  180.619
# C(stim, Treatment)[T.1]    23.818   17.436  1.366  0.172  -10.357   57.992
# 1 | mouse                  34.525   23.882  1.446  0.148  -12.283   81.332
# Group Var                1977.327   14.675
# 0it [00:00, ?it/s]/home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# 2it [00:00, 11.57it/s]
# Power~stim
#              sum_sq   df    F  PR(>F)
# stim         22.40  1.0  0.0    0.96
# Residual  44877.96  6.0  NaN     NaN
# Using formula Power ~  C(stim, Treatment) + (1 | mouse)
#                            Coef. Std.Err.      z  P>|z|   [0.025   0.975]
# Intercept                 88.511   58.860  1.504  0.133  -26.852  203.875
# C(stim, Treatment)[T.1]    3.346   47.070  0.071  0.943  -88.910   95.602
# 1 | mouse                 54.516   24.127  2.260  0.024    7.227  101.804
# Group Var                112.881    7.033
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2200: ConvergenceWarning: Retrying MixedLM optimization with lbfgs
#   warnings.warn(
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# 2it [00:00,  5.22it/s]
# 4it [00:26,  6.60s/it]
# 4it [00:27,  6.97s/it]
# 4it [00:31,  7.97s/it]
# 3it [00:09,  3.89s/it]
# 0it [00:00, ?it/s]
# Power~stim
#                sum_sq   df     F  PR(>F)
# stim       312000.82  1.0  0.87    0.39
# Residual  2145103.78  6.0   NaN     NaN
# Using formula Power ~  C(stim, Treatment) + (1 | mouse)
#                            Coef. Std.Err.      z  P>|z|    [0.025    0.975]
# Intercept                 15.475
# C(stim, Treatment)[T.1]  394.969  370.451  1.066  0.286  -331.101  1121.039
# 1 | mouse                -40.027
# Group Var                  0.000
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2200: ConvergenceWarning: Retrying MixedLM optimization with lbfgs
#   warnings.warn(
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# 2it [00:00,  9.24it/s]
# 2it [00:00, 11.18it/s]
# Power~stim
#               sum_sq   df     F  PR(>F)
# stim      178622.61  1.0  1.48    0.27
# Residual  722744.54  6.0   NaN     NaN
# Using formula Power ~  C(stim, Treatment) + (1 | mouse)
#                            Coef. Std.Err.      z  P>|z|    [0.025   0.975]
# Intercept                -35.473
# C(stim, Treatment)[T.1]  298.850  263.268  1.135  0.256  -217.145  814.845
# 1 | mouse                 91.755
# Group Var                  0.000
# 2it [00:12, 14.66it/s]
# 2it [00:16, 13.29it/s]
# 0it [00:00, ?it/s]
# Power~stim
#                  sum_sq   df     F  PR(>F)
# stim      1.811048e+07  1.0  0.97    0.36
# Residual  1.120492e+08  6.0   NaN     NaN
# Using formula Power ~  C(stim, Treatment) + (1 | mouse)
#                              Coef.  Std.Err.  ...     [0.025    0.975]
# Intercept                 -388.117            ...
# C(stim, Treatment)[T.1]  -3009.193  2962.844  ...  -8816.261  2797.875
# 1 | mouse                 1003.907            ...
# Group Var                    0.000            ...
#
# [4 rows x 6 columns]
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2200: ConvergenceWarning: Retrying MixedLM optimization with lbfgs
#   warnings.warn(
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# 2it [00:00, 11.01it/s]
# 3it [00:13,  5.52s/it]
#   8%|███████████▏                                                                                                                                | 36/450 [00:50<11:11,  1.62s/it]
# 4it [00:17,  4.49s/it]
# 4it [00:18,  4.69s/it]
# 3it [00:10,  4.46s/it]
# 3it [00:18,  7.82s/it]
# 2it [00:19, 11.57it/s]
# 4it [00:21,  5.26s/it]
# 0it [00:00, ?it/s]
# Power~stim
#              sum_sq   df     F  PR(>F)
# stim       8103.36  1.0  0.98    0.36
# Residual  49417.77  6.0   NaN     NaN
# Using formula Power ~  C(stim, Treatment) + (1 | mouse)
#                            Coef. Std.Err.       z  P>|z|    [0.025   0.975]
# Intercept                 82.394   52.784   1.561  0.119   -21.060  185.849
# C(stim, Treatment)[T.1]  -63.653   37.009  -1.720  0.085  -136.189    8.884
# 1 | mouse                 51.493   22.108   2.329  0.020     8.163   94.823
# Group Var                585.298   11.968
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2200: ConvergenceWarning: Retrying MixedLM optimization with lbfgs
#   warnings.warn(
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# 2it [00:00,  9.80it/s]
# 0it [00:00, ?it/s]/home/m/env_jb1/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2200: ConvergenceWarning: Retrying MixedLM optimization with lbfgs
#   warnings.warn(
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# 2it [00:00, 10.31it/s]
# Power~stim
#               sum_sq   df     F  PR(>F)
# stim      169642.32  1.0  1.54    0.26
# Residual  660969.62  6.0   NaN     NaN
# Using formula Power ~  C(stim, Treatment) + (1 | mouse)
#                             Coef. Std.Err.       z  P>|z|    [0.025   0.975]
# Intercept                -191.511  288.491  -0.664  0.507  -756.942  373.921
# C(stim, Treatment)[T.1]   291.241  227.725   1.279  0.201  -155.091  737.573
# 1 | mouse                 163.042  118.543   1.375  0.169   -69.298  395.382
# Group Var                4351.301   69.423
# 4it [00:23,  5.95s/it]
# 0it [00:00, ?it/s]
# Power~stim
#              sum_sq   df     F  PR(>F)
# stim       5942.64  1.0  0.56    0.48
# Residual  63980.23  6.0   NaN     NaN
# Using formula Power ~  C(stim, Treatment) + (1 | mouse)
#                             Coef. Std.Err.      z  P>|z|    [0.025   0.975]
# Intercept                  20.071   79.445  0.253  0.801  -135.639  175.781
# C(stim, Treatment)[T.1]    54.510   56.784  0.960  0.337   -56.784  165.804
# 1 | mouse                  63.292   33.183  1.907  0.056    -1.745  128.329
# Group Var                1179.990   17.573
# 2it [00:11, 11.01it/s]/home/m/env_jb1/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2200: ConvergenceWarning: Retrying MixedLM optimization with lbfgs
#   warnings.warn(
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# 2it [00:00,  9.58it/s]
# 3it [00:12,  5.08s/it]
# 2it [00:16, 11.18it/s]
# 4it [00:19,  4.78s/it]
# 4it [00:27,  6.94s/it]
# 4it [00:27,  6.86s/it]
# 2it [00:00, 13.36it/s]
# 0it [00:00, ?it/s]
# Power~stim
#              sum_sq   df     F  PR(>F)
# stim       1567.33  1.0  0.13    0.73
# Residual  73563.17  6.0   NaN     NaN
# Using formula Power ~  C(stim, Treatment) + (1 | mouse)
#                            Coef. Std.Err.       z  P>|z|    [0.025   0.975]
# Intercept                 24.733
# C(stim, Treatment)[T.1]  -27.994   82.723  -0.338  0.735  -190.128  134.140
# 1 | mouse                -63.974
# Group Var                  0.000
# Power~stim
#              sum_sq   df     F  PR(>F)
# stim        733.80  1.0  0.18    0.68
# Residual  24235.67  6.0   NaN     NaN
# Using formula Power ~  C(stim, Treatment) + (1 | mouse)
#                             Coef. Std.Err.      z  P>|z|   [0.025   0.975]
# Intercept                 119.223   63.881  1.866  0.062   -5.982  244.427
# C(stim, Treatment)[T.1]    19.155   34.222  0.560  0.576  -47.919   86.229
# 1 | mouse                  27.759   27.525  1.009  0.313  -26.188   81.706
# Group Var                1859.265    7.497
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2200: ConvergenceWarning: Retrying MixedLM optimization with lbfgs
#   warnings.warn(
# 2it [00:00,  9.17it/s]
# 0it [00:00, ?it/s]
# Power~stim
#               sum_sq   df     F  PR(>F)
# stim       13532.22  1.0  0.56    0.48
# Residual  144283.63  6.0   NaN     NaN
# Using formula Power ~  C(stim, Treatment) + (1 | mouse)
#                              Coef. Std.Err.       z  P>|z|    [0.025   0.975]
# Intercept                  100.830  137.618   0.733  0.464  -168.895  370.555
# C(stim, Treatment)[T.1]    -82.256   64.399  -1.277  0.201  -208.475   43.962
# 1 | mouse                   77.626   59.836   1.297  0.195   -39.651  194.902
# Group Var                10174.271   18.828
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2200: ConvergenceWarning: Retrying MixedLM optimization with lbfgs
#   warnings.warn(
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# 2it [00:00,  9.15it/s]
# 4it [00:20,  5.18s/it]
# Power~stim
#               sum_sq   df     F  PR(>F)
# stim       19516.38  1.0  1.16    0.32
# Residual  100894.32  6.0   NaN     NaN
# Using formula Power ~  C(stim, Treatment) + (1 | mouse)
#                            Coef. Std.Err.       z  P>|z|    [0.025   0.975]
# Intercept                100.926  104.757   0.963  0.335  -104.394  306.246
# C(stim, Treatment)[T.1]  -98.784   85.534  -1.155  0.248  -266.427   68.860
# 1 | mouse                 70.043   42.767   1.638  0.101   -13.779  153.865
# Group Var                  0.000   16.918
# 2it [00:00, 10.06it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# Power~stim
#               sum_sq   df     F  PR(>F)
# stim       14104.24  1.0  0.42    0.54
# Residual  201421.19  6.0   NaN     NaN
# Using formula Power ~  C(stim, Treatment) + (1 | mouse)
#                              Coef. Std.Err.       z  P>|z|    [0.025   0.975]
# Intercept                   50.516  154.099   0.328  0.743  -251.513  352.544
# C(stim, Treatment)[T.1]    -83.977   83.591  -1.005  0.315  -247.813   79.859
# 1 | mouse                  100.150   66.332   1.510  0.131   -29.859  230.158
# Group Var                10612.147   29.929
# Power~stim
#               sum_sq   df     F  PR(>F)
# stim      133725.01  1.0  1.73    0.24
# Residual  462491.38  6.0   NaN     NaN
# Using formula Power ~  C(stim, Treatment) + (1 | mouse)
#                             Coef. Std.Err.       z  P>|z|    [0.025    0.975]
# Intercept                 532.925  252.777   2.108  0.035    37.491  1028.359
# C(stim, Treatment)[T.1]  -258.578  202.653  -1.276  0.202  -655.770   138.614
# 1 | mouse                 -49.887  103.566  -0.482  0.630  -252.872   153.098
# Group Var                1835.249   17.925
# 2it [00:00, 13.05it/s]
# 4it [00:20,  5.09s/it]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# Power~stim
#              sum_sq   df    F  PR(>F)
# stim          1.71  1.0  0.0    0.99
# Residual  36447.92  6.0  NaN     NaN
# Using formula Power ~  C(stim, Treatment) + (1 | mouse)
#                             Coef. Std.Err.       z  P>|z|   [0.025   0.975]
# Intercept                  90.937   63.389   1.435  0.151  -33.304  215.177
# C(stim, Treatment)[T.1]    -0.925   31.180  -0.030  0.976  -62.037   60.187
# 1 | mouse                  46.408   27.478   1.689  0.091   -7.448  100.263
# Group Var                2047.909   10.861
# n(Divergences) = 1
# Power~stim
#              sum_sq   df     F  PR(>F)
# stim       1832.72  1.0  0.21    0.66
# Residual  51680.78  6.0   NaN     NaN
# Using formula Power ~  C(stim, Treatment) + (1 | mouse)
#                            Coef. Std.Err.       z  P>|z|    [0.025   0.975]
# Intercept                 55.505   73.863   0.751  0.452   -89.263  200.274
# C(stim, Treatment)[T.1]  -30.271   60.304  -0.502  0.616  -148.465   87.922
# 1 | mouse                 67.808   30.155   2.249  0.025     8.705  126.911
# Group Var                  0.750
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2200: ConvergenceWarning: Retrying MixedLM optimization with lbfgs
#   warnings.warn(
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2200: ConvergenceWarning: Retrying MixedLM optimization with cg
#   warnings.warn(
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 0.369885
#   warnings.warn(msg, ConvergenceWarning)
# 2it [00:00,  9.01it/s]
# 2it [00:00, 13.71it/s]
# Power~stim
#              sum_sq   df     F  PR(>F)
# stim        923.57  1.0  0.47    0.52
# Residual  11689.45  6.0   NaN     NaN
# Using formula Power ~  C(stim, Treatment) + (1 | mouse)
#                            Coef. Std.Err.       z  P>|z|   [0.025  0.975]
# Intercept                  5.238
# C(stim, Treatment)[T.1]  -21.489   18.206  -1.180  0.238  -57.173  14.195
# 1 | mouse                -13.550
# Group Var                  0.000
# 3it [00:14,  6.11s/it]
# 3it [00:08,  3.72s/it]
# 3it [00:09,  4.09s/it]
# 3it [00:14,  6.16s/it]
# 2it [00:19, 10.31it/s]
# 2it [00:17, 13.36it/s]
#  11%|██████████████▉                                                                                                                             | 48/450 [01:21<13:26,  2.01s/it]
# 4it [00:22,  5.62s/it]
# 4it [00:24,  6.08s/it]
# 4it [00:18,  4.61s/it]
# 2it [00:15, 13.05it/s]
# 4it [00:24,  6.04s/it]
# 3it [00:17,  7.43s/it]
# 2it [00:19, 10.06it/s]
# 0it [00:00, ?it/s]
# Power~stim
#               sum_sq   df     F  PR(>F)
# stim         914.68  1.0  0.01    0.92
# Residual  526902.28  6.0   NaN     NaN
# Using formula Power ~  C(stim, Treatment) + (1 | mouse)
#                            Coef. Std.Err.       z  P>|z|    [0.025   0.975]
# Intercept                -35.015  260.205  -0.135  0.893  -545.006  474.977
# C(stim, Treatment)[T.1]  -21.386  212.455  -0.101  0.920  -437.790  395.018
# 1 | mouse                188.986  106.228   1.779  0.075   -19.217  397.190
# Group Var                  0.659
# 0it [00:00, ?it/s]/home/m/env_jb1/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2200: ConvergenceWarning: Retrying MixedLM optimization with lbfgs
#   warnings.warn(
# 2it [00:00, 13.31it/s]
# Power~stim
#              sum_sq   df     F  PR(>F)
# stim         91.04  1.0  0.01    0.92
# Residual  54871.23  6.0   NaN     NaN
# Using formula Power ~  C(stim, Treatment) + (1 | mouse)
#                           Coef. Std.Err.       z  P>|z|    [0.025   0.975]
# Intercept                -2.314
# C(stim, Treatment)[T.1]  -6.747   57.278  -0.118  0.906  -119.010  105.516
# 1 | mouse                 5.985
# Group Var                 0.000
# Power~stim
#               sum_sq   df    F  PR(>F)
# stim        2079.62  1.0  0.1    0.76
# Residual  121350.02  6.0  NaN     NaN
# Using formula Power ~  C(stim, Treatment) + (1 | mouse)
#                            Coef. Std.Err.       z  P>|z|    [0.025   0.975]
# Intercept                 38.375
# C(stim, Treatment)[T.1]  -32.246   77.468  -0.416  0.677  -184.080  119.588
# 1 | mouse                -99.261
# Group Var                  0.000
# 0it [00:00, ?it/s]
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2200: ConvergenceWarning: Retrying MixedLM optimization with lbfgs
#   warnings.warn(
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2200: ConvergenceWarning: Retrying MixedLM optimization with cg
#   warnings.warn(
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 0.176793
#   warnings.warn(msg, ConvergenceWarning)
# 2it [00:00,  5.80it/s]
# 3it [00:19,  8.08s/it]
# Power~stim
#              sum_sq   df     F  PR(>F)
# stim       7708.83  1.0  0.84    0.39
# Residual  54830.43  6.0   NaN     NaN
# Using formula Power ~  C(stim, Treatment) + (1 | mouse)
#                            Coef. Std.Err.       z  P>|z|    [0.025   0.975]
# Intercept                198.155   96.187   2.060  0.039     9.632  386.678
# C(stim, Treatment)[T.1]  -62.084   75.741  -0.820  0.412  -210.534   86.366
# 1 | mouse                 -2.764   39.542  -0.070  0.944   -80.264   74.736
# Group Var                517.472   50.791
# 0it [00:00, ?it/s]
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2200: ConvergenceWarning: Retrying MixedLM optimization with lbfgs
#   warnings.warn(
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# 2it [00:00,  9.53it/s]
# 2it [00:18, 13.71it/s]
# 0it [00:00, ?it/s]
# Power~stim
#              sum_sq   df    F  PR(>F)
# stim          1.45  1.0  0.0    0.99
# Residual  23570.85  6.0  NaN     NaN
# Using formula Power ~  C(stim, Treatment) + (1 | mouse)
#                            Coef. Std.Err.       z  P>|z|   [0.025   0.975]
# Intercept                 57.055   32.364   1.763  0.078   -6.378  120.487
# C(stim, Treatment)[T.1]   -0.851   22.795  -0.037  0.970  -45.528   43.826
# 1 | mouse                 46.617   13.547   3.441  0.001   20.066   73.167
# Group Var                214.427    7.296
# n(Divergences) = 1
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2200: ConvergenceWarning: Retrying MixedLM optimization with lbfgs
#   warnings.warn(
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# 2it [00:00,  9.92it/s]
# 4it [00:23,  5.83s/it]
# 4it [00:24,  6.12s/it]
# 0it [00:00, ?it/s]
# Power~stim
#                sum_sq   df     F  PR(>F)
# stim      1194392.60  1.0  0.73    0.43
# Residual  9869262.63  6.0   NaN     NaN
# Using formula Power ~  C(stim, Treatment) + (1 | mouse)
#                             Coef. Std.Err.       z  P>|z|     [0.025   0.975]
# Intercept                 105.570
# C(stim, Treatment)[T.1]  -772.785  895.828  -0.863  0.388  -2528.576  983.006
# 1 | mouse                -273.069
# Group Var                   0.000
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2200: ConvergenceWarning: Retrying MixedLM optimization with lbfgs
#   warnings.warn(
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# 4it [00:22,  5.73s/it]
# 4it [00:22,  5.62s/it]
# 4it [00:27,  6.97s/it]
# 0it [00:00, ?it/s]
# Power~stim
#               sum_sq   df     F  PR(>F)
# stim      105865.65  1.0  1.49    0.27
# Residual  425934.41  6.0   NaN     NaN
# Using formula Power ~  C(stim, Treatment) + (1 | mouse)
#                              Coef. Std.Err.      z  P>|z|    [0.025   0.975]
# Intercept                  101.285  319.369  0.317  0.751  -524.667  727.236
# C(stim, Treatment)[T.1]    230.071  229.041  1.004  0.315  -218.841  678.984
# 1 | mouse                   55.800  133.328  0.419  0.676  -205.518  317.118
# Group Var                18645.377   44.140
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2200: ConvergenceWarning: Retrying MixedLM optimization with lbfgs
#   warnings.warn(
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2200: ConvergenceWarning: Retrying MixedLM optimization with cg
#   warnings.warn(
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 0.046005
#   warnings.warn(msg, ConvergenceWarning)
# ...
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2200: ConvergenceWarning: Retrying MixedLM optimization with lbfgs
#   warnings.warn(
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2200: ConvergenceWarning: Retrying MixedLM optimization with cg
#   warnings.warn(
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 0.052156
#   warnings.warn(msg, ConvergenceWarning)
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# 2it [00:00,  4.63it/s]2021-11-25 02:16:23.505286: E external/org_tensorflow/tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_COMPAT_NOT_SUPPORTED_ON_DEVICE: forward compatibility was attempted on non supported HW
# 2021-11-25 02:16:23.505559: E external/org_tensorflow/tensorflow/stream_executor/cuda/cuda_diagnostics.cc:313] kernel version 450.142.0 does not match DSO version 450.156.0 -- cannot find working devices in this configuration
# 2it [00:20, 13.74it/s]
# 0it [00:00, ?it/s]
# Power~stim
#              sum_sq   df     F  PR(>F)
# stim       8630.07  1.0  1.81    0.23
# Residual  28614.01  6.0   NaN     NaN
# Using formula Power ~  C(stim, Treatment) + (1 | mouse)
#                           Coef. Std.Err.      z  P>|z|   [0.025   0.975]
# Intercept                58.026   39.449  1.471  0.141  -19.293  135.345
# C(stim, Treatment)[T.1]  65.689   32.210  2.039  0.041    2.558  128.820
# 1 | mouse                50.938   16.105  3.163  0.002   19.373   82.504
# Group Var                 0.000
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# 2it [00:00,  8.73it/s]
# 3it [00:15,  6.37s/it]
# 2it [00:00,  9.22it/s]2021-11-25 02:16:25.719160: E external/org_tensorflow/tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_COMPAT_NOT_SUPPORTED_ON_DEVICE: forward compatibility was attempted on non supported HW
# 2021-11-25 02:16:25.719484: E external/org_tensorflow/tensorflow/stream_executor/cuda/cuda_diagnostics.cc:313] kernel version 450.142.0 does not match DSO version 450.156.0 -- cannot find working devices in this configuration
# 3it [00:10,  4.21s/it]
# 0it [00:00, ?it/s]
# Power~stim
#               sum_sq   df    F  PR(>F)
# stim          77.92  1.0  0.0    0.96
# Residual  199933.29  6.0  NaN     NaN
# Using formula Power ~  C(stim, Treatment) + (1 | mouse)
#                             Coef. Std.Err.       z  P>|z|    [0.025   0.975]
# Intercept                 373.640  200.687   1.862  0.063   -19.699  766.979
# C(stim, Treatment)[T.1]     6.242  136.973   0.046  0.964  -262.221  274.705
# 1 | mouse                 -53.226   84.362  -0.631  0.528  -218.573  112.121
# Group Var                9706.164   23.310
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2200: ConvergenceWarning: Retrying MixedLM optimization with lbfgs
#   warnings.warn(
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2200: ConvergenceWarning: Retrying MixedLM optimization with cg
#   warnings.warn(
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 1.294769
#   warnings.warn(msg, ConvergenceWarning)
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# 4it [00:25,  6.31s/it]
# 4it [00:23,  5.76s/it]
# 4it [00:23,  5.78s/it]
# 3it [00:12,  5.30s/it]
# 3it [00:14,  6.10s/it]
# 2it [00:00, 12.57it/s]
# Power~stim
#                sum_sq   df     F  PR(>F)
# stim       775536.97  1.0  1.16    0.32
# Residual  4026182.92  6.0   NaN     NaN
# Using formula Power ~  C(stim, Treatment) + (1 | mouse)
#                             Coef. Std.Err.       z  P>|z|    [0.025    0.975]
# Intercept                 692.089  669.795   1.033  0.301  -620.686  2004.863
# C(stim, Treatment)[T.1]   622.711  543.274   1.146  0.252  -442.088  1687.509
# 1 | mouse                -259.386  273.802  -0.947  0.343  -796.029   277.257
# Group Var                4723.979   55.423
# 4it [00:18,  4.59s/it]
# 2it [00:17, 10.21it/s]
# 3it [00:13,  5.40s/it]
# 0it [00:00, ?it/s]
# Power~stim
#              sum_sq   df    F  PR(>F)
# stim      11216.74  1.0  1.0    0.36
# Residual  67057.66  6.0  NaN     NaN
# Using formula Power ~  C(stim, Treatment) + (1 | mouse)
#                           Coef. Std.Err.      z  P>|z|   [0.025   0.975]
# Intercept                -3.498
# C(stim, Treatment)[T.1]  74.889   50.450  1.484  0.138  -23.991  173.769
# 1 | mouse                 9.048
# Group Var                 0.000
# 2it [00:00,  8.35it/s]
# 2it [00:00, 12.32it/s]
# Power~stim
#              sum_sq   df     F  PR(>F)
# stim       1798.85  1.0  0.32    0.59
# Residual  33325.66  6.0   NaN     NaN
# Using formula Power ~  C(stim, Treatment) + (1 | mouse)
#                           Coef. Std.Err.      z  P>|z|   [0.025   0.975]
# Intercept                -8.372
# C(stim, Treatment)[T.1]  29.990   43.791  0.685  0.493  -55.838  115.819
# 1 | mouse                21.655
# Group Var                 0.000
# 4it [00:20,  5.24s/it]
# Power~stim
#               sum_sq   df     F  PR(>F)
# stim        1231.24  1.0  0.04    0.85
# Residual  199289.41  6.0   NaN     NaN
# Using formula Power ~  C(stim, Treatment) + (1 | mouse)
#                            Coef. Std.Err.      z  P>|z|    [0.025   0.975]
# Intercept                -21.561
# C(stim, Treatment)[T.1]   24.812  163.048  0.152  0.879  -294.757  344.380
# 1 | mouse                 55.771
# Group Var                  0.000
# 2it [00:00, 13.56it/s]
# 3it [00:11,  4.83s/it]
# 4it [00:23,  5.99s/it]
# 0it [00:00, ?it/s]
# Power~stim
#             sum_sq   df     F  PR(>F)
# stim      79251.6  1.0  8.42    0.03
# Residual  56442.6  6.0   NaN     NaN
# Using formula Power ~  C(stim, Treatment) + (1 | mouse)
#                            Coef. Std.Err.       z  P>|z|    [0.025   0.975]
# Intercept                210.123  142.854   1.471  0.141   -69.866  490.112
# C(stim, Treatment)[T.1]  199.062  116.639   1.707  0.088   -29.546  427.671
# 1 | mouse                -27.222   58.320  -0.467  0.641  -141.527   87.084
# Group Var                  0.208
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2200: ConvergenceWarning: Retrying MixedLM optimization with lbfgs
#   warnings.warn(
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# 2it [00:00,  9.64it/s]
# 4it [00:25,  6.34s/it]
# Power~stim
#               sum_sq   df     F  PR(>F)
# stim      117423.54  1.0  1.11    0.33
# Residual  635391.39  6.0   NaN     NaN
# Using formula Power ~  C(stim, Treatment) + (1 | mouse)
#                             Coef. Std.Err.       z  P>|z|    [0.025   0.975]
# Intercept                 158.088  292.165   0.541  0.588  -414.545  730.722
# C(stim, Treatment)[T.1]  -242.305  230.572  -1.051  0.293  -694.218  209.607
# 1 | mouse                 136.520  120.058   1.137  0.255   -98.790  371.829
# Group Var                4492.374   21.174
# 4it [00:21,  5.41s/it]
# 4it [00:21,  5.40s/it]
# 3it [00:12,  5.34s/it]
# 3it [00:22,  9.40s/it]/home/m/env_jb1/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2200: ConvergenceWarning: Retrying MixedLM optimization with lbfgs
#   warnings.warn(
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# 2it [00:00, 10.44it/s]
# Power~stim
#              sum_sq   df     F  PR(>F)
# stim       5805.32  1.0  0.74    0.42
# Residual  46917.23  6.0   NaN     NaN
# Using formula Power ~  C(stim, Treatment) + (1 | mouse)
#                           Coef. Std.Err.      z  P>|z|   [0.025   0.975]
# Intercept                19.057   51.748  0.368  0.713  -82.368  120.481
# C(stim, Treatment)[T.1]  53.876   42.252  1.275  0.202  -28.936  136.689
# 1 | mouse                67.558   21.126  3.198  0.001   26.152  108.965
# Group Var                 0.021
# 0it [00:00, ?it/s]/home/m/env_jb1/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2200: ConvergenceWarning: Retrying MixedLM optimization with lbfgs
#   warnings.warn(
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# 2it [00:00, 10.26it/s]
# Power~stim
#               sum_sq   df    F  PR(>F)
# stim       14154.88  1.0  0.7    0.44
# Residual  121481.00  6.0  NaN     NaN
# Using formula Power ~  C(stim, Treatment) + (1 | mouse)
#                             Coef. Std.Err.       z  P>|z|    [0.025   0.975]
# Intercept                 256.779  156.201   1.644  0.100   -49.369  562.927
# C(stim, Treatment)[T.1]    84.128  109.012   0.772  0.440  -129.532  297.787
# 1 | mouse                 -22.959   65.464  -0.351  0.726  -151.266  105.349
# Group Var                5258.649   13.316
# 2it [00:10, 13.56it/s]
# 3it [00:11,  4.61s/it]
# 4it [00:22,  5.69s/it]
# 0it [00:00, ?it/s]
# Power~stim
#              sum_sq   df     F  PR(>F)
# stim      45189.87  1.0  4.63    0.07
# Residual  58595.73  6.0   NaN     NaN
# Using formula Power ~  C(stim, Treatment) + (1 | mouse)
#                            Coef. Std.Err.      z  P>|z|    [0.025   0.975]
# Intercept                 10.113   95.611  0.106  0.916  -177.280  197.507
# C(stim, Treatment)[T.1]  150.316   78.063  1.926  0.054    -2.685  303.317
# 1 | mouse                 66.492   39.033  1.703  0.088   -10.012  142.996
# Group Var                  0.490
# 2it [00:17, 12.32it/s]
# Power~stim
#              sum_sq   df    F  PR(>F)
# stim      22302.11  1.0  4.8    0.07
# Residual  27851.95  6.0  NaN     NaN
# Using formula Power ~  C(stim, Treatment) + (1 | mouse)
#                            Coef. Std.Err.       z  P>|z|   [0.025   0.975]
# Intercept                182.422   85.695   2.129  0.033   14.463  350.380
# C(stim, Treatment)[T.1]  105.599   69.969   1.509  0.131  -31.539  242.736
# 1 | mouse                -14.983   34.985  -0.428  0.668  -83.552   53.586
# Group Var                  0.001   12.392
# 0it [00:00, ?it/s]
# 2it [00:00,  7.91it/s]
# 4it [00:22,  5.72s/it]
# 3it [00:13,  5.80s/it]
# 4it [00:20,  5.19s/it]
# Power~stim
#                sum_sq   df     F  PR(>F)
# stim       160528.21  1.0  0.68    0.44
# Residual  1419577.16  6.0   NaN     NaN
# Using formula Power ~  C(stim, Treatment) + (1 | mouse)
#                              Coef. Std.Err.       z  P>|z|    [0.025   0.975]
# Intercept                   95.539  415.233   0.230  0.818  -718.302  909.380
# C(stim, Treatment)[T.1]   -283.309  251.063  -1.128  0.259  -775.384  208.766
# 1 | mouse                  188.439  177.008   1.065  0.287  -158.491  535.369
# Group Var                62295.160   55.981
# 4it [00:20,  5.02s/it]
# 2it [00:00, 10.19it/s]
# 2021-11-25 02:16:58.474584: E external/org_tensorflow/tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_COMPAT_NOT_SUPPORTED_ON_DEVICE: forward compatibility was attempted on non supported HW
# 2021-11-25 02:16:58.474873: E external/org_tensorflow/tensorflow/stream_executor/cuda/cuda_diagnostics.cc:313] kernel version 450.142.0 does not match DSO version 450.156.0 -- cannot find working devices in this configuration
# 4it [00:33,  8.32s/it]
# 2it [00:11, 10.44it/s]
# 4it [00:19,  4.80s/it]
# 2it [00:11, 10.26it/s]
# 3it [00:15,  6.25s/it]
# 3it [00:13,  5.63s/it]
# 4it [00:22,  5.57s/it]
# 4it [00:23,  5.84s/it]
# Power~stim
#               sum_sq   df     F  PR(>F)
# stim       44739.72  1.0  0.43    0.54
# Residual  630614.32  6.0   NaN     NaN
# Using formula Power ~  C(stim, Treatment) + (1 | mouse)
#                             Coef. Std.Err.       z  P>|z|    [0.025   0.975]
# Intercept                 -12.732
# C(stim, Treatment)[T.1]  -149.566  212.683  -0.703  0.482  -566.417  267.285
# 1 | mouse                  32.932
# Group Var                   0.000
# 3it [00:17,  7.25s/it]
# 3it [00:16,  6.91s/it]
# 2it [00:20, 10.19it/s]
# 4it [00:24,  6.09s/it]
# 4it [00:24,  6.19s/it]

# %%
# NBVAL_SKIP
model_comparison.plot_confusion(
    model_comparison.make_confusion_matrix(res[res['y'] == 'Power'], ('method', 'y', 'randomness', 'n_trials')
                                           )).properties(width=140).facet(row='method', column='n_trials')
# Out:
# alt.FacetChart(...)

# %%
df = model_comparison.make_roc_auc(res, binary=False, groups=('method', 'y', 'n_trials'))

bars, roc = model_comparison.plot_roc(df)
bars.facet(column='n_trials', row='y').properties().display()
roc.facet(column='n_trials', row='y').properties()
# NBVAL_SKIP
# Out:
# alt.FacetChart(...)
# alt.FacetChart(...)

# %%
reslog = model_comparison.run_conditions(true_slopes=np.hstack([np.zeros(15),
                                                                np.tile(10, 15)]),
                                         #                                                              np.tile(np.linspace(20, 40, 3), 15)]),
                                         n_trials=np.linspace(10, 70, 5).astype(int),
                                         #                                       trial_baseline_randomness=np.linspace(.2, 11, 3),
                                         ys=('Log power',),
                                         parallel=True)
# NBVAL_SKIP
# Out:
#   0%|                                                                                                                                                     | 0/450 [00:00<?, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# Power~stim
#               sum_sq   df     F  PR(>F)
# stim        3288.82  1.0  0.18    0.69
# Residual  110779.51  6.0   NaN     NaN
# Using formula Power ~  C(stim, Treatment) + (1 | mouse)
#                            Coef. Std.Err.      z  P>|z|    [0.025   0.975]
# Intercept                180.810  127.395  1.419  0.156   -68.879  430.500
# C(stim, Treatment)[T.1]   40.551  103.450  0.392  0.695  -162.207  243.309
# 1 | mouse                 49.600   52.065  0.953  0.341   -52.447  151.646
# Group Var                141.353
# Power~stim
#              sum_sq   df     F  PR(>F)
# stim      21076.06  1.0  2.18    0.19
# Residual  57920.70  6.0   NaN     NaN
# Using formula Power ~  C(stim, Treatment) + (1 | mouse)
#                             Coef. Std.Err.      z  P>|z|   [0.025   0.975]
# Intercept                 132.909  114.399  1.162  0.245  -91.309  357.126
# C(stim, Treatment)[T.1]   102.655   61.017  1.682  0.092  -16.937  222.247
# 1 | mouse                  19.519   49.308  0.396  0.692  -77.123  116.160
# Group Var                6001.942   22.657
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2200: ConvergenceWarning: Retrying MixedLM optimization with lbfgs
#   warnings.warn(
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# 2it [00:00,  9.27it/s]/home/m/env_jb1/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2200: ConvergenceWarning: Retrying MixedLM optimization with lbfgs
#   warnings.warn(
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# 2it [00:00,  8.29it/s]
# 0it [00:00, ?it/s]
# Power~stim
#              sum_sq   df     F  PR(>F)
# stim       5835.54  1.0  0.85    0.39
# Residual  41347.14  6.0   NaN     NaN
# Using formula Power ~  C(stim, Treatment) + (1 | mouse)
#                             Coef. Std.Err.      z  P>|z|   [0.025   0.975]
# Intercept                 158.618  105.969  1.497  0.134  -49.077  366.313
# C(stim, Treatment)[T.1]    54.016   60.229  0.897  0.370  -64.030  172.063
# 1 | mouse                  24.306   45.437  0.535  0.593  -64.748  113.361
# Group Var                4630.515   15.374
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# 2it [00:00, 12.90it/s]
# 2it [00:00, 13.14it/s]
# Power~stim
#              sum_sq   df    F  PR(>F)
# stim       1337.28  1.0  0.2    0.67
# Residual  39611.60  6.0  NaN     NaN
# Using formula Power ~  C(stim, Treatment) + (1 | mouse)
#                            Coef. Std.Err.      z  P>|z|   [0.025   0.975]
# Intercept                  5.249
# C(stim, Treatment)[T.1]   25.858   53.543  0.483  0.629  -79.084  130.801
# 1 | mouse                -13.576
# Group Var                  0.000
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]/home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# 2it [00:00, 12.58it/s]
# Power~stim
#                sum_sq   df     F  PR(>F)
# stim       198426.80  1.0  1.13    0.33
# Residual  1052395.63  6.0   NaN     NaN
# Using formula Power ~  C(stim, Treatment) + (1 | mouse)
#                              Coef. Std.Err.       z  P>|z|    [0.025   0.975]
# Intercept                 -198.893  342.431  -0.581  0.561  -870.046  472.260
# C(stim, Treatment)[T.1]    314.982  213.512   1.475  0.140  -103.494  733.457
# 1 | mouse                  177.315  145.508   1.219  0.223  -107.874  462.505
# Group Var                39102.702   44.489
# Power~stim
#                sum_sq   df     F  PR(>F)
# stim      1029568.22  1.0  1.35    0.29
# Residual  4577294.06  6.0   NaN     NaN
# Using formula Power ~  C(stim, Treatment) + (1 | mouse)
#                              Coef. Std.Err.       z  P>|z|     [0.025    0.975]
# Intercept                 -535.368  702.860  -0.762  0.446  -1912.947   842.211
# C(stim, Treatment)[T.1]    717.485  550.077   1.304  0.192   -360.647  1795.616
# 1 | mouse                  345.028  289.263   1.193  0.233   -221.917   911.973
# Group Var                32107.635   51.513
# 0it [00:00, ?it/s]/home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# 2it [00:00, 12.45it/s]
# Power~stim
#              sum_sq   df     F  PR(>F)
# stim      43583.18  1.0  4.87    0.07
# Residual  53711.64  6.0   NaN     NaN
# Using formula Power ~  C(stim, Treatment) + (1 | mouse)
#                             Coef. Std.Err.      z  P>|z|   [0.025   0.975]
# Intercept                 116.471   89.352  1.304  0.192  -58.656  291.598
# C(stim, Treatment)[T.1]   147.620   64.147  2.301  0.021   21.893  273.346
# 1 | mouse                  28.511   37.296  0.764  0.445  -44.588  101.611
# Group Var                1449.210    7.344
# 0it [00:00, ?it/s]
# 2it [00:00, 11.47it/s]
# Power~stim
#              sum_sq   df     F  PR(>F)
# stim      17398.09  1.0  5.89    0.05
# Residual  17711.82  6.0   NaN     NaN
# Using formula Power ~  C(stim, Treatment) + (1 | mouse)
#                            Coef. Std.Err.      z  P>|z|   [0.025   0.975]
# Intercept                129.252   48.586  2.660  0.008   34.025  224.478
# C(stim, Treatment)[T.1]   93.269   34.768  2.683  0.007   25.124  161.413
# 1 | mouse                 15.172   20.290  0.748  0.455  -24.595   54.939
# Group Var                437.867    4.010
# Power~stim
#                sum_sq   df     F  PR(>F)
# stim        84405.74  1.0  0.49    0.51
# Residual  1041434.04  6.0   NaN     NaN
# Using formula Power ~  C(stim, Treatment) + (1 | mouse)
#                             Coef. Std.Err.       z  P>|z|    [0.025   0.975]
# Intercept                  -8.394
# C(stim, Treatment)[T.1]  -205.433  311.223  -0.660  0.509  -815.420  404.553
# 1 | mouse                  21.711
# Group Var                   0.000
# 2it [00:00, 13.52it/s]
# Power~stim
#              sum_sq   df     F  PR(>F)
# stim      78824.57  1.0  5.47    0.06
# Residual  86506.14  6.0   NaN     NaN
# Using formula Power ~  C(stim, Treatment) + (1 | mouse)
#                             Coef. Std.Err.       z  P>|z|    [0.025   0.975]
# Intercept                 154.735  125.137   1.237  0.216   -90.529  400.000
# C(stim, Treatment)[T.1]   198.525   94.284   2.106  0.035    13.731  383.319
# 1 | mouse                  -0.434   51.840  -0.008  0.993  -102.038  101.171
# Group Var                1860.033    9.653
# 0it [00:00, ?it/s]
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# 2it [00:00,  8.52it/s]
# 0it [00:00, ?it/s]
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# 2it [00:00, 10.14it/s]/home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# 2it [00:00,  9.06it/s]2021-11-25 02:17:34.276169: E external/org_tensorflow/tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_COMPAT_NOT_SUPPORTED_ON_DEVICE: forward compatibility was attempted on non supported HW
# 2021-11-25 02:17:34.276425: E external/org_tensorflow/tensorflow/stream_executor/cuda/cuda_diagnostics.cc:313] kernel version 450.142.0 does not match DSO version 450.156.0 -- cannot find working devices in this configuration
# 2021-11-25 02:17:34.286430: E external/org_tensorflow/tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_COMPAT_NOT_SUPPORTED_ON_DEVICE: forward compatibility was attempted on non supported HW
# 2021-11-25 02:17:34.286740: E external/org_tensorflow/tensorflow/stream_executor/cuda/cuda_diagnostics.cc:313] kernel version 450.142.0 does not match DSO version 450.156.0 -- cannot find working devices in this configuration
# 3it [00:11,  4.92s/it]
# 3it [00:12,  5.02s/it]
# 2it [00:13, 12.75it/s]
# 2it [00:13, 11.47it/s]
#   5%|███████▍                                                                                                                                    | 24/450 [00:20<06:09,  1.15it/s]
# 2it [00:15, 12.45it/s]
# Log_power~stim
#            sum_sq   df     F  PR(>F)
# stim        0.01  1.0  0.46    0.52
# Residual    0.17  6.0   NaN     NaN
# Using formula Log_power ~  C(stim, Treatment) + (1 | mouse)
#                          Coef. Std.Err.       z  P>|z|  [0.025 0.975]
# Intercept                1.875    0.115  16.275  0.000   1.649  2.101
# C(stim, Treatment)[T.1]  0.082    0.091   0.899  0.369  -0.097  0.260
# 1 | mouse                0.112    0.047   2.362  0.018   0.019  0.205
# Group Var                0.001    0.022
# 4it [00:19,  4.98s/it]
# 2it [00:18, 12.58it/s]
# 3it [00:17,  7.12s/it]
# 3it [00:17,  7.32s/it]
# 2it [00:19, 13.52it/s]
# 4it [00:25,  6.41s/it]
# Log_power~stim
#            sum_sq   df     F  PR(>F)
# stim        0.01  1.0  0.55    0.49
# Residual    0.15  6.0   NaN     NaN
# Using formula Log_power ~  C(stim, Treatment) + (1 | mouse)
#                          Coef. Std.Err.       z  P>|z|  [0.025 0.975]
# Intercept                1.825    0.127  14.393  0.000   1.576  2.073
# C(stim, Treatment)[T.1]  0.082    0.041   1.987  0.047   0.001  0.163
# 1 | mouse                0.109    0.056   1.956  0.050  -0.000  0.219
# Group Var                0.011    0.043
# 3it [00:21,  9.13s/it]
# 2it [00:20, 10.14it/s]/home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# 2it [00:00, 11.66it/s]
# Log_power~stim
#            sum_sq   df     F  PR(>F)
# stim         0.0  1.0  0.13    0.73
# Residual     0.2  6.0   NaN     NaN
# Using formula Log_power ~  C(stim, Treatment) + (1 | mouse)
#                          Coef. Std.Err.       z  P>|z|  [0.025 0.975]
# Intercept                1.747    0.108  16.244  0.000   1.537  1.958
# C(stim, Treatment)[T.1]  0.047    0.088   0.534  0.594  -0.125  0.219
# 1 | mouse                0.140    0.044   3.182  0.001   0.054  0.226
# Group Var                0.000
# 4it [00:26,  6.75s/it]
# 0it [00:00, ?it/s]
# Log_power~stim
#            sum_sq   df    F  PR(>F)
# stim        0.00  1.0  0.0    0.95
# Residual    0.18  6.0  NaN     NaN
# Using formula Log_power ~  C(stim, Treatment) + (1 | mouse)
#                           Coef. Std.Err.       z  P>|z|  [0.025 0.975]
# Intercept                 1.815    0.100  18.239  0.000   1.620  2.010
# C(stim, Treatment)[T.1]  -0.009    0.038  -0.227  0.821  -0.083  0.065
# 1 | mouse                 0.133    0.044   3.042  0.002   0.047  0.219
# Group Var                 0.006    0.029
# Log_power~stim
#            sum_sq   df     F  PR(>F)
# stim        0.00  1.0  0.03    0.86
# Residual    0.17  6.0   NaN     NaN
# Using formula Log_power ~  C(stim, Treatment) + (1 | mouse)
#                           Coef. Std.Err.       z  P>|z|  [0.025 0.975]
# Intercept                 1.811    0.084  21.687  0.000   1.647  1.975
# C(stim, Treatment)[T.1]  -0.022    0.068  -0.328  0.743  -0.156  0.111
# 1 | mouse                 0.134    0.034   3.939  0.000   0.067  0.201
# Group Var                 0.000    0.014
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# 2it [00:00, 13.88it/s]
# 4it [00:26,  6.57s/it]
# Log_power~stim
#            sum_sq   df     F  PR(>F)
# stim        0.00  1.0  0.06    0.82
# Residual    0.14  6.0   NaN     NaN
# Using formula Log_power ~  C(stim, Treatment) + (1 | mouse)
#                           Coef. Std.Err.       z  P>|z|  [0.025 0.975]
# Intercept                 1.912    0.146  13.116  0.000   1.626  2.197
# C(stim, Treatment)[T.1]  -0.025    0.039  -0.648  0.517  -0.102  0.051
# 1 | mouse                 0.092    0.065   1.431  0.152  -0.034  0.219
# Group Var                 0.015    0.061
# 0it [00:00, ?it/s]
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# 2it [00:00,  8.49it/s]
# Log_power~stim
#            sum_sq   df     F  PR(>F)
# stim        0.00  1.0  0.24    0.64
# Residual    0.12  6.0   NaN     NaN
# Using formula Log_power ~  C(stim, Treatment) + (1 | mouse)
#                          Coef. Std.Err.       z  P>|z|  [0.025 0.975]
# Intercept                1.892    0.083  22.821  0.000   1.729  2.054
# C(stim, Treatment)[T.1]  0.049    0.044   1.100  0.271  -0.038  0.136
# 1 | mouse                0.099    0.036   2.780  0.005   0.029  0.169
# Group Var                0.003    0.013
# 4it [00:26,  6.73s/it]
# 0it [00:00, ?it/s]/home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# 2it [00:00, 10.75it/s]
# 3it [00:23,  9.95s/it]2021-11-25 02:17:57.964329: E external/org_tensorflow/tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_COMPAT_NOT_SUPPORTED_ON_DEVICE: forward compatibility was attempted on non supported HW
# 2021-11-25 02:17:57.964599: E external/org_tensorflow/tensorflow/stream_executor/cuda/cuda_diagnostics.cc:313] kernel version 450.142.0 does not match DSO version 450.156.0 -- cannot find working devices in this configuration
# 0it [00:00, ?it/s]/home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# 3it [00:24, 10.32s/it]2021-11-25 02:17:58.850779: E external/org_tensorflow/tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_COMPAT_NOT_SUPPORTED_ON_DEVICE: forward compatibility was attempted on non supported HW
# 2021-11-25 02:17:58.851075: E external/org_tensorflow/tensorflow/stream_executor/cuda/cuda_diagnostics.cc:313] kernel version 450.142.0 does not match DSO version 450.156.0 -- cannot find working devices in this configuration
# 0it [00:00, ?it/s]
# Log_power~stim
#            sum_sq   df     F  PR(>F)
# stim        0.00  1.0  0.15    0.71
# Residual    0.17  6.0   NaN     NaN
# Using formula Log_power ~  C(stim, Treatment) + (1 | mouse)
#                          Coef. Std.Err.       z  P>|z|  [0.025 0.975]
# Intercept                1.816    0.128  14.150  0.000   1.565  2.068
# C(stim, Treatment)[T.1]  0.047    0.036   1.326  0.185  -0.023  0.117
# 1 | mouse                0.120    0.057   2.115  0.034   0.009  0.232
# Group Var                0.012    0.041
# 0it [00:00, ?it/s]/home/m/env_jb1/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2200: ConvergenceWarning: Retrying MixedLM optimization with lbfgs
#   warnings.warn(
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# 2it [00:00,  6.51it/s]/home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# 2it [00:00, 12.57it/s]
# 2021-11-25 02:18:00.548245: E external/org_tensorflow/tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_COMPAT_NOT_SUPPORTED_ON_DEVICE: forward compatibility was attempted on non supported HW
# 2021-11-25 02:18:00.548712: E external/org_tensorflow/tensorflow/stream_executor/cuda/cuda_diagnostics.cc:313] kernel version 450.142.0 does not match DSO version 450.156.0 -- cannot find working devices in this configuration
#
# 0it [00:00, ?it/s]
# Log_power~stim
#            sum_sq   df     F  PR(>F)
# stim        0.00  1.0  0.01    0.95
# Residual    0.12  6.0   NaN     NaN
# Using formula Log_power ~  C(stim, Treatment) + (1 | mouse)
#                           Coef. Std.Err.       z  P>|z|  [0.025 0.975]
# Intercept                 1.875    0.120  15.568  0.000   1.639  2.110
# C(stim, Treatment)[T.1]  -0.007    0.034  -0.211  0.833  -0.074  0.060
# 1 | mouse                 0.090    0.053   1.694  0.090  -0.014  0.195
# Group Var                 0.010    0.037
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# 2it [00:00, 13.36it/s]
# 4it [00:31,  7.80s/it]
# 0it [00:00, ?it/s]
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2200: ConvergenceWarning: Retrying MixedLM optimization with lbfgs
#   warnings.warn(
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# 2it [00:00,  7.62it/s]2021-11-25 02:18:05.086574: E external/org_tensorflow/tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_COMPAT_NOT_SUPPORTED_ON_DEVICE: forward compatibility was attempted on non supported HW
# 2021-11-25 02:18:05.086874: E external/org_tensorflow/tensorflow/stream_executor/cuda/cuda_diagnostics.cc:313] kernel version 450.142.0 does not match DSO version 450.156.0 -- cannot find working devices in this configuration
# 3it [00:11,  4.95s/it]
# 0it [00:00, ?it/s]
# Log_power~stim
#            sum_sq   df     F  PR(>F)
# stim        0.01  1.0  0.35    0.57
# Residual    0.10  6.0   NaN     NaN
# Using formula Log_power ~  C(stim, Treatment) + (1 | mouse)
#                           Coef. Std.Err.       z  P>|z|  [0.025 0.975]
# Intercept                 1.924    0.092  20.904  0.000   1.743  2.104
# C(stim, Treatment)[T.1]  -0.054    0.029  -1.862  0.063  -0.111  0.003
# 1 | mouse                 0.095    0.041   2.341  0.019   0.015  0.175
# Group Var                 0.006    0.022
# 4it [00:34,  8.74s/it]/home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# 2it [00:00,  9.35it/s]
# 4it [00:35,  8.86s/it]
# 2it [00:12, 12.57it/s]
# 2it [00:19, 11.66it/s]
# 2it [00:19, 13.88it/s]
# 0it [00:00, ?it/s]/home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# 2it [00:00, 14.10it/s]
# Log_power~stim
#            sum_sq   df     F  PR(>F)
# stim        0.00  1.0  0.05    0.82
# Residual    0.16  6.0   NaN     NaN
# Using formula Log_power ~  C(stim, Treatment) + (1 | mouse)
#                          Coef. Std.Err.       z  P>|z|  [0.025 0.975]
# Intercept                1.819    0.111  16.335  0.000   1.601  2.037
# C(stim, Treatment)[T.1]  0.027    0.031   0.891  0.373  -0.033  0.087
# 1 | mouse                0.123    0.049   2.484  0.013   0.026  0.219
# Group Var                0.009    0.030
# 0it [00:00, ?it/s]/home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# 3it [00:15,  6.29s/it]
# Log_power~stim
#            sum_sq   df    F  PR(>F)
# stim         0.0  1.0  0.0    0.98
# Residual     0.1  6.0  NaN     NaN
# Using formula Log_power ~  C(stim, Treatment) + (1 | mouse)
#                           Coef. Std.Err.       z  P>|z|  [0.025 0.975]
# Intercept                 1.941    0.098  19.869  0.000   1.749  2.132
# C(stim, Treatment)[T.1]  -0.003    0.031  -0.091  0.928  -0.063  0.057
# 1 | mouse                 0.087    0.043   2.006  0.045   0.002  0.171
# Group Var                 0.007    0.023
#   8%|███████████▏                                                                                                                                | 36/450 [00:52<11:00,  1.60s/it]
# 3it [00:15,  6.43s/it]
# 2it [00:20, 10.75it/s]
# 2it [00:20, 13.40it/s]
# 2it [00:19, 13.36it/s]
# 4it [00:21,  5.48s/it]
# 3it [00:18,  7.62s/it]
# 0it [00:00, ?it/s]
# Log_power~stim
#            sum_sq   df     F  PR(>F)
# stim        0.00  1.0  0.02    0.88
# Residual    0.16  6.0   NaN     NaN
# Using formula Log_power ~  C(stim, Treatment) + (1 | mouse)
#                          Coef. Std.Err.       z  P>|z|  [0.025 0.975]
# Intercept                1.763    0.111  15.855  0.000   1.545  1.981
# C(stim, Treatment)[T.1]  0.018    0.056   0.321  0.748  -0.092  0.128
# 1 | mouse                0.122    0.048   2.529  0.011   0.027  0.216
# Group Var                0.006    0.037
# n(Divergences) = 1
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# 2it [00:00, 10.15it/s]
# 4it [00:24,  6.01s/it]
# 3it [00:17,  7.06s/it]
# 4it [00:25,  6.41s/it]
# Log_power~stim
#            sum_sq   df     F  PR(>F)
# stim        0.00  1.0  0.11    0.75
# Residual    0.07  6.0   NaN     NaN
# Using formula Log_power ~  C(stim, Treatment) + (1 | mouse)
#                          Coef. Std.Err.       z  P>|z|  [0.025 0.975]
# Intercept                1.941    0.094  20.660  0.000   1.757  2.125
# C(stim, Treatment)[T.1]  0.026    0.048   0.549  0.583  -0.068  0.120
# 1 | mouse                0.069    0.041   1.709  0.087  -0.010  0.149
# Group Var                0.004    0.020
# n(Divergences) = 1
# 4it [00:26,  6.70s/it]
# 0it [00:00, ?it/s]
# Log_power~stim
#            sum_sq   df    F  PR(>F)
# stim        0.00  1.0  0.1    0.76
# Residual    0.21  6.0  NaN     NaN
# Using formula Log_power ~  C(stim, Treatment) + (1 | mouse)
#                          Coef. Std.Err.       z  P>|z|  [0.025 0.975]
# Intercept                1.805    0.107  16.902  0.000   1.596  2.014
# C(stim, Treatment)[T.1]  0.042    0.084   0.504  0.614  -0.122  0.207
# 1 | mouse                0.118    0.044   2.683  0.007   0.032  0.204
# Group Var                0.001    0.021
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2200: ConvergenceWarning: Retrying MixedLM optimization with lbfgs
#   warnings.warn(
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2200: ConvergenceWarning: Retrying MixedLM optimization with cg
#   warnings.warn(
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 0.566679
#   warnings.warn(msg, ConvergenceWarning)
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# 2it [00:00,  4.44it/s]
# Log_power~stim
#            sum_sq   df     F  PR(>F)
# stim        0.02  1.0  0.32    0.59
# Residual    0.29  6.0   NaN     NaN
# Using formula Log_power ~  C(stim, Treatment) + (1 | mouse)
#                          Coef. Std.Err.       z  P>|z| [0.025 0.975]
# Intercept                1.667    0.115  14.538  0.000  1.442  1.892
# C(stim, Treatment)[T.1]  0.088    0.042   2.080  0.037  0.005  0.170
# 1 | mouse                0.173    0.050   3.442  0.001  0.075  0.272
# Group Var                0.008    0.034
# n(Divergences) = 1
# 3it [00:36, 15.20s/it]
# 3it [00:37, 15.58s/it]
# 0it [00:00, ?it/s]/home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# 2it [00:00, 10.15it/s]
# Log_power~stim
#            sum_sq   df     F  PR(>F)
# stim        0.03  1.0  1.05    0.34
# Residual    0.15  6.0   NaN     NaN
# Using formula Log_power ~  C(stim, Treatment) + (1 | mouse)
#                          Coef. Std.Err.       z  P>|z|  [0.025 0.975]
# Intercept                1.784    0.076  23.376  0.000   1.634  1.933
# C(stim, Treatment)[T.1]  0.113    0.062   1.813  0.070  -0.009  0.235
# 1 | mouse                0.128    0.031   4.110  0.000   0.067  0.189
# Group Var                0.000
# 2it [00:19, 14.10it/s]
# 4it [00:25,  6.42s/it]
# 2it [00:12, 10.15it/s]
# 0it [00:00, ?it/s]
# Log_power~stim
#            sum_sq   df     F  PR(>F)
# stim        0.00  1.0  0.02    0.91
# Residual    0.11  6.0   NaN     NaN
# Using formula Log_power ~  C(stim, Treatment) + (1 | mouse)
#                          Coef. Std.Err.       z  P>|z|  [0.025 0.975]
# Intercept                1.884    0.086  21.803  0.000   1.715  2.054
# C(stim, Treatment)[T.1]  0.012    0.039   0.309  0.757  -0.064  0.088
# 1 | mouse                0.103    0.038   2.721  0.007   0.029  0.176
# Group Var                0.004    0.016
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2200: ConvergenceWarning: Retrying MixedLM optimization with lbfgs
#   warnings.warn(
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2200: ConvergenceWarning: Retrying MixedLM optimization with cg
#   warnings.warn(
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 0.046330
#   warnings.warn(msg, ConvergenceWarning)
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# 2it [00:00,  5.69it/s]
# 3it [00:40, 17.04s/it]
# 0it [00:00, ?it/s]/home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# 2it [00:00, 11.29it/s]
# 2021-11-25 02:18:40.930505: E external/org_tensorflow/tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_COMPAT_NOT_SUPPORTED_ON_DEVICE: forward compatibility was attempted on non supported HW
# 2021-11-25 02:18:40.930784: E external/org_tensorflow/tensorflow/stream_executor/cuda/cuda_diagnostics.cc:313] kernel version 450.142.0 does not match DSO version 450.156.0 -- cannot find working devices in this configuration
# 4it [00:26,  6.60s/it]
# 4it [00:26,  6.54s/it]
# 0it [00:00, ?it/s]
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# 2it [00:00, 14.52it/s]2021-11-25 02:18:42.068558: E external/org_tensorflow/tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_COMPAT_NOT_SUPPORTED_ON_DEVICE: forward compatibility was attempted on non supported HW
# 2021-11-25 02:18:42.068889: E external/org_tensorflow/tensorflow/stream_executor/cuda/cuda_diagnostics.cc:313] kernel version 450.142.0 does not match DSO version 450.156.0 -- cannot find working devices in this configuration
# Log_power~stim
#            sum_sq   df     F  PR(>F)
# stim        0.00  1.0  0.01    0.92
# Residual    0.15  6.0   NaN     NaN
# Using formula Log_power ~  C(stim, Treatment) + (1 | mouse)
#                          Coef. Std.Err.       z  P>|z|  [0.025 0.975]
# Intercept                1.833    0.105  17.447  0.000   1.627  2.039
# C(stim, Treatment)[T.1]  0.012    0.023   0.504  0.615  -0.034  0.057
# 1 | mouse                0.118    0.047   2.520  0.012   0.026  0.209
# Group Var                0.008    0.032
# Log_power~stim
#            sum_sq   df    F  PR(>F)
# stim        0.00  1.0  0.0     1.0
# Residual    0.12  6.0  NaN     NaN
# Using formula Log_power ~  C(stim, Treatment) + (1 | mouse)
#                           Coef. Std.Err.       z  P>|z|  [0.025 0.975]
# Intercept                 1.876    0.098  19.060  0.000   1.683  2.069
# C(stim, Treatment)[T.1]  -0.000    0.038  -0.008  0.994  -0.076  0.075
# 1 | mouse                 0.107    0.043   2.488  0.013   0.023  0.192
# Group Var                 0.006    0.022
# Log_power~stim
#            sum_sq   df    F  PR(>F)
# stim        0.00  1.0  0.1    0.76
# Residual    0.14  6.0  NaN     NaN
# Using formula Log_power ~  C(stim, Treatment) + (1 | mouse)
#                          Coef. Std.Err.       z  P>|z|  [0.025 0.975]
# Intercept                1.853    0.113  16.380  0.000   1.631  2.075
# C(stim, Treatment)[T.1]  0.035    0.036   0.972  0.331  -0.036  0.106
# 1 | mouse                0.109    0.050   2.178  0.029   0.011  0.207
# Group Var                0.009    0.031
# n(Divergences) = 1
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]/home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# 2it [00:00, 12.80it/s]
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# 2it [00:00, 15.90it/s]
# Log_power~stim
#            sum_sq   df     F  PR(>F)
# stim        0.00  1.0  0.02     0.9
# Residual    0.17  6.0   NaN     NaN
# Using formula Log_power ~  C(stim, Treatment) + (1 | mouse)
#                           Coef. Std.Err.       z  P>|z|  [0.025 0.975]
# Intercept                 1.834    0.103  17.744  0.000   1.632  2.037
# C(stim, Treatment)[T.1]  -0.016    0.027  -0.592  0.554  -0.069  0.037
# 1 | mouse                 0.124    0.046   2.704  0.007   0.034  0.214
# Group Var                 0.008    0.026
# Log_power~stim
#            sum_sq   df     F  PR(>F)
# stim        0.00  1.0  0.11    0.75
# Residual    0.14  6.0   NaN     NaN
# Using formula Log_power ~  C(stim, Treatment) + (1 | mouse)
#                           Coef. Std.Err.      z  P>|z|  [0.025 0.975]
# Intercept                 0.019
# C(stim, Treatment)[T.1]   0.036    0.051  0.706  0.480  -0.064  0.136
# 1 | mouse                -0.104
# Group Var                 0.000
# 0it [00:00, ?it/s]/home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# 2it [00:00, 10.46it/s]
# 3it [00:23,  9.69s/it]
# 3it [00:11,  4.81s/it]
# 4it [00:51, 12.88s/it]
# 0it [00:00, ?it/s]
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2200: ConvergenceWarning: Retrying MixedLM optimization with lbfgs
#   warnings.warn(
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# 3it [00:22,  9.25s/it]2021-11-25 02:18:50.694717: E external/org_tensorflow/tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_COMPAT_NOT_SUPPORTED_ON_DEVICE: forward compatibility was attempted on non supported HW
# 2021-11-25 02:18:50.695049: E external/org_tensorflow/tensorflow/stream_executor/cuda/cuda_diagnostics.cc:313] kernel version 450.142.0 does not match DSO version 450.156.0 -- cannot find working devices in this configuration
# 2it [00:00, 12.88it/s]
# 2021-11-25 02:18:52.682135: E external/org_tensorflow/tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_COMPAT_NOT_SUPPORTED_ON_DEVICE: forward compatibility was attempted on non supported HW
# 2021-11-25 02:18:52.682427: E external/org_tensorflow/tensorflow/stream_executor/cuda/cuda_diagnostics.cc:313] kernel version 450.142.0 does not match DSO version 450.156.0 -- cannot find working devices in this configuration
# 0it [00:00, ?it/s]/home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# 2it [00:00, 11.21it/s]
# Log_power~stim
#            sum_sq   df     F  PR(>F)
# stim        0.00  1.0  0.12    0.74
# Residual    0.13  6.0   NaN     NaN
# Using formula Log_power ~  C(stim, Treatment) + (1 | mouse)
#                          Coef. Std.Err.       z  P>|z|  [0.025 0.975]
# Intercept                1.839    0.062  29.736  0.000   1.717  1.960
# C(stim, Treatment)[T.1]  0.037    0.029   1.264  0.206  -0.020  0.094
# 1 | mouse                0.120    0.027   4.469  0.000   0.067  0.173
# Group Var                0.002    0.008
# 3it [00:11,  4.73s/it]
# 3it [00:22,  9.21s/it]
# 2it [00:10, 10.46it/s]
# 3it [00:12,  5.33s/it]
#  11%|██████████████▉                                                                                                                             | 48/450 [01:32<15:09,  2.26s/it]
# Log_power~stim
#            sum_sq   df     F  PR(>F)
# stim        0.04  1.0  4.32    0.08
# Residual    0.05  6.0   NaN     NaN
# Using formula Log_power ~  C(stim, Treatment) + (1 | mouse)
#                           Coef. Std.Err.       z  P>|z|  [0.025 0.975]
# Intercept                 2.153    0.126  17.025  0.000   1.905  2.401
# C(stim, Treatment)[T.1]  -0.134    0.103  -1.296  0.195  -0.336  0.069
# 1 | mouse                 0.033    0.052   0.635  0.525  -0.068  0.134
# Group Var                 0.000
# 4it [00:33,  8.43s/it]
# Log_power~stim
#            sum_sq   df    F  PR(>F)
# stim        0.00  1.0  0.0    0.97
# Residual    0.14  6.0  NaN     NaN
# Using formula Log_power ~  C(stim, Treatment) + (1 | mouse)
#                          Coef. Std.Err.       z  P>|z|  [0.025 0.975]
# Intercept                1.845    0.109  16.969  0.000   1.632  2.058
# C(stim, Treatment)[T.1]  0.005    0.029   0.163  0.870  -0.052  0.062
# 1 | mouse                0.115    0.048   2.386  0.017   0.021  0.209
# Group Var                0.008    0.031
# 2it [00:20, 11.29it/s]
# 4it [00:32,  8.24s/it]
# 2it [00:20, 14.52it/s]
# 4it [00:19,  4.90s/it]
# 4it [00:20,  5.24s/it]
# 4it [00:32,  8.13s/it]
# 0it [00:00, ?it/s]/home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# 2it [00:00, 13.71it/s]
# 2021-11-25 02:19:06.234759: E external/org_tensorflow/tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_COMPAT_NOT_SUPPORTED_ON_DEVICE: forward compatibility was attempted on non supported HW
# 2021-11-25 02:19:06.235015: E external/org_tensorflow/tensorflow/stream_executor/cuda/cuda_diagnostics.cc:313] kernel version 450.142.0 does not match DSO version 450.156.0 -- cannot find working devices in this configuration
# 0it [00:00, ?it/s]/home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# 2it [00:00, 11.39it/s]
# Log_power~stim
#            sum_sq   df    F  PR(>F)
# stim        0.00  1.0  0.0    0.96
# Residual    0.11  6.0  NaN     NaN
# Using formula Log_power ~  C(stim, Treatment) + (1 | mouse)
#                          Coef. Std.Err.       z  P>|z|  [0.025 0.975]
# Intercept                1.899    0.109  17.415  0.000   1.685  2.112
# C(stim, Treatment)[T.1]  0.005    0.030   0.158  0.875  -0.053  0.063
# 1 | mouse                0.091    0.048   1.890  0.059  -0.003  0.186
# Group Var                0.008    0.033
# 2it [00:14, 11.21it/s]
# 1it [00:00,  9.27it/s]
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# 2it [00:00,  8.20it/s]2021-11-25 02:19:08.450833: E external/org_tensorflow/tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_COMPAT_NOT_SUPPORTED_ON_DEVICE: forward compatibility was attempted on non supported HW
# 2021-11-25 02:19:08.451280: E external/org_tensorflow/tensorflow/stream_executor/cuda/cuda_diagnostics.cc:313] kernel version 450.142.0 does not match DSO version 450.156.0 -- cannot find working devices in this configuration
# 3it [00:15,  6.53s/it]
# 3it [00:18,  7.80s/it]
# 0it [00:00, ?it/s]
# Log_power~stim
#            sum_sq   df     F  PR(>F)
# stim        0.01  1.0  0.39    0.56
# Residual    0.22  6.0   NaN     NaN
# Using formula Log_power ~  C(stim, Treatment) + (1 | mouse)
#                          Coef. Std.Err.       z  P>|z|  [0.025 0.975]
# Intercept                1.733    0.118  14.662  0.000   1.501  1.965
# C(stim, Treatment)[T.1]  0.085    0.063   1.355  0.176  -0.038  0.208
# 1 | mouse                0.149    0.051   2.917  0.004   0.049  0.249
# Group Var                0.006    0.038
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2200: ConvergenceWarning: Retrying MixedLM optimization with lbfgs
#   warnings.warn(
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2200: ConvergenceWarning: Retrying MixedLM optimization with cg
#   warnings.warn(
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 1.525221
#   warnings.warn(msg, ConvergenceWarning)
# 2it [00:00,  5.30it/s]
# 0it [00:00, ?it/s]
# Log_power~stim
#            sum_sq   df    F  PR(>F)
# stim        0.04  1.0  1.6    0.25
# Residual    0.14  6.0  NaN     NaN
# Using formula Log_power ~  C(stim, Treatment) + (1 | mouse)
#                           Coef. Std.Err.       z  P>|z|  [0.025 0.975]
# Intercept                 2.072    0.104  19.889  0.000   1.867  2.276
# C(stim, Treatment)[T.1]  -0.137    0.071  -1.942  0.052  -0.276  0.001
# 1 | mouse                 0.051    0.044   1.160  0.246  -0.035  0.137
# Group Var                 0.003    0.025
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# 2it [00:00,  9.48it/s]
# 2it [00:20, 12.88it/s]/home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# 2it [00:00, 11.14it/s]
# Log_power~stim
#            sum_sq   df     F  PR(>F)
# stim         0.0  1.0  0.08    0.78
# Residual     0.1  6.0   NaN     NaN
# Using formula Log_power ~  C(stim, Treatment) + (1 | mouse)
#                          Coef. Std.Err.       z  P>|z|  [0.025 0.975]
# Intercept                1.885    0.082  23.087  0.000   1.725  2.045
# C(stim, Treatment)[T.1]  0.026    0.027   0.974  0.330  -0.027  0.079
# 1 | mouse                0.097    0.036   2.702  0.007   0.027  0.168
# Group Var                0.004    0.018
# 3it [00:38, 15.84s/it]
# 4it [00:26,  6.64s/it]
# 3it [00:39, 16.40s/it]
# 4it [00:29,  7.34s/it]
# 3it [00:38, 16.01s/it]
# 3it [00:17,  7.27s/it]
# 3it [00:20,  8.35s/it]
# 0it [00:00, ?it/s]/home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# 2it [00:00, 14.22it/s]
# Log_power~stim
#            sum_sq   df     F  PR(>F)
# stim        0.00  1.0  0.13    0.73
# Residual    0.16  6.0   NaN     NaN
# Using formula Log_power ~  C(stim, Treatment) + (1 | mouse)
#                           Coef. Std.Err.       z  P>|z|  [0.025 0.975]
# Intercept                 1.824    0.071  25.522  0.000   1.684  1.964
# C(stim, Treatment)[T.1]  -0.042    0.046  -0.907  0.364  -0.132  0.049
# 1 | mouse                 0.135    0.030   4.464  0.000   0.076  0.194
# Group Var                 0.002    0.010
# 3it [00:20,  9.36s/it]
# 0it [00:00, ?it/s]
# Log_power~stim
#            sum_sq   df    F  PR(>F)
# stim        0.00  1.0  0.2    0.67
# Residual    0.09  6.0  NaN     NaN
# Using formula Log_power ~  C(stim, Treatment) + (1 | mouse)
#                          Coef. Std.Err.       z  P>|z|  [0.025 0.975]
# Intercept                1.870    0.057  32.766  0.000   1.758  1.982
# C(stim, Treatment)[T.1]  0.038    0.047   0.823  0.410  -0.053  0.130
# 1 | mouse                0.098    0.023   4.213  0.000   0.053  0.144
# Group Var                0.000    0.012
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# 2it [00:00, 12.13it/s]
# 2it [00:17, 11.14it/s]
# Log_power~stim
#            sum_sq   df     F  PR(>F)
# stim        0.00  1.0  0.01    0.94
# Residual    0.15  6.0   NaN     NaN
# Using formula Log_power ~  C(stim, Treatment) + (1 | mouse)
#                          Coef. Std.Err.       z  P>|z|  [0.025 0.975]
# Intercept                1.813    0.082  22.058  0.000   1.652  1.974
# C(stim, Treatment)[T.1]  0.009    0.024   0.393  0.694  -0.037  0.056
# 1 | mouse                0.125    0.036   3.434  0.001   0.054  0.196
# Group Var                0.005    0.019
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2200: ConvergenceWarning: Retrying MixedLM optimization with lbfgs
#   warnings.warn(
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# 2it [00:00,  9.73it/s]
# Log_power~stim
#            sum_sq   df     F  PR(>F)
# stim        0.00  1.0  0.03    0.87
# Residual    0.22  6.0   NaN     NaN
# Using formula Log_power ~  C(stim, Treatment) + (1 | mouse)
#                          Coef. Std.Err.       z  P>|z|  [0.025 0.975]
# Intercept                1.807    0.133  13.584  0.000   1.547  2.068
# ...
# C(stim, Treatment)[T.1]  0.164    0.041   4.039  0.000  0.085  0.244
# 1 | mouse                0.119    0.020   5.834  0.000  0.079  0.159
# Group Var                0.000    0.008
# 0it [00:00, ?it/s]
# 2it [00:00, 11.12it/s]/home/m/env_jb1/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2200: ConvergenceWarning: Retrying MixedLM optimization with lbfgs
#   warnings.warn(
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# 2it [00:00,  8.03it/s]2021-11-25 02:39:54.972507: E external/org_tensorflow/tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_COMPAT_NOT_SUPPORTED_ON_DEVICE: forward compatibility was attempted on non supported HW
# 2021-11-25 02:39:54.972801: E external/org_tensorflow/tensorflow/stream_executor/cuda/cuda_diagnostics.cc:313] kernel version 450.142.0 does not match DSO version 450.156.0 -- cannot find working devices in this configuration
# 4it [00:26,  6.54s/it]
# Log_power~stim
#            sum_sq   df     F  PR(>F)
# stim        0.04  1.0  2.56    0.16
# Residual    0.10  6.0   NaN     NaN
# Using formula Log_power ~  C(stim, Treatment) + (1 | mouse)
#                          Coef. Std.Err.       z  P>|z| [0.025 0.975]
# Intercept                1.860    0.082  22.617  0.000  1.698  2.021
# C(stim, Treatment)[T.1]  0.149    0.032   4.703  0.000  0.087  0.211
# 1 | mouse                0.091    0.036   2.519  0.012  0.020  0.162
# Group Var                0.004    0.018
# 4it [00:26,  6.62s/it]
# 2it [00:20, 10.18it/s]
# Log_power~stim
#            sum_sq   df     F  PR(>F)
# stim        0.08  1.0  5.01    0.07
# Residual    0.09  6.0   NaN     NaN
# Using formula Log_power ~  C(stim, Treatment) + (1 | mouse)
#                          Coef. Std.Err.       z  P>|z| [0.025 0.975]
# Intercept                1.846    0.081  22.803  0.000  1.687  2.005
# C(stim, Treatment)[T.1]  0.195    0.034   5.713  0.000  0.128  0.262
# 1 | mouse                0.091    0.035   2.569  0.010  0.022  0.160
# Group Var                0.004    0.016
# 3it [00:21,  9.09s/it]/home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# 2it [00:00, 14.09it/s]
# 0it [00:00, ?it/s]/home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# 2it [00:00, 15.09it/s]2021-11-25 02:40:00.654704: E external/org_tensorflow/tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_COMPAT_NOT_SUPPORTED_ON_DEVICE: forward compatibility was attempted on non supported HW
# 2021-11-25 02:40:00.654941: E external/org_tensorflow/tensorflow/stream_executor/cuda/cuda_diagnostics.cc:313] kernel version 450.142.0 does not match DSO version 450.156.0 -- cannot find working devices in this configuration
# 2it [00:12, 15.02it/s]
# 3it [00:24, 10.34s/it]
# 0it [00:00, ?it/s]
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# 2it [00:00,  9.70it/s]2021-11-25 02:40:03.930368: E external/org_tensorflow/tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_COMPAT_NOT_SUPPORTED_ON_DEVICE: forward compatibility was attempted on non supported HW
# 2021-11-25 02:40:03.930660: E external/org_tensorflow/tensorflow/stream_executor/cuda/cuda_diagnostics.cc:313] kernel version 450.142.0 does not match DSO version 450.156.0 -- cannot find working devices in this configuration
# 2it [00:15, 14.19it/s]
# 2it [00:14, 13.43it/s]
# 4it [00:32,  8.04s/it]
# 4it [00:19,  5.00s/it]
# Log_power~stim
#            sum_sq   df     F  PR(>F)
# stim        0.09  1.0  2.62    0.16
# Residual    0.20  6.0   NaN     NaN
# Using formula Log_power ~  C(stim, Treatment) + (1 | mouse)
#                          Coef. Std.Err.       z  P>|z| [0.025 0.975]
# Intercept                1.836    0.150  12.253  0.000  1.542  2.129
# C(stim, Treatment)[T.1]  0.211    0.085   2.480  0.013  0.044  0.378
# 1 | mouse                0.130    0.064   2.021  0.043  0.004  0.256
# Group Var                0.009    0.044
# 4it [00:32,  8.04s/it]
# Log_power~stim
#            sum_sq   df     F  PR(>F)
# stim        0.06  1.0  2.52    0.16
# Residual    0.15  6.0   NaN     NaN
# Using formula Log_power ~  C(stim, Treatment) + (1 | mouse)
#                          Coef. Std.Err.       z  P>|z| [0.025 0.975]
# Intercept                1.839    0.101  18.287  0.000  1.641  2.036
# C(stim, Treatment)[T.1]  0.178    0.069   2.593  0.010  0.043  0.313
# 1 | mouse                0.093    0.042   2.203  0.028  0.010  0.176
# Group Var                0.002    0.024
# 4it [00:34,  8.74s/it]
# Log_power~stim
#            sum_sq   df     F  PR(>F)
# stim        0.03  1.0  0.66    0.45
# Residual    0.28  6.0   NaN     NaN
# Using formula Log_power ~  C(stim, Treatment) + (1 | mouse)
#                          Coef. Std.Err.       z  P>|z|  [0.025 0.975]
# Intercept                1.858    0.178  10.421  0.000   1.509  2.207
# C(stim, Treatment)[T.1]  0.125    0.061   2.031  0.042   0.004  0.245
# 1 | mouse                0.132    0.079   1.683  0.092  -0.022  0.286
# Group Var                0.021    0.091
# n(Divergences) = 1
# 1it [00:00,  8.08it/s]
# Log_power~stim
#            sum_sq   df     F  PR(>F)
# stim        0.03  1.0  2.04     0.2
# Residual    0.09  6.0   NaN     NaN
# Using formula Log_power ~  C(stim, Treatment) + (1 | mouse)
#                          Coef. Std.Err.       z  P>|z| [0.025 0.975]
# Intercept                1.897    0.085  22.249  0.000  1.730  2.064
# C(stim, Treatment)[T.1]  0.126    0.026   4.911  0.000  0.075  0.176
# 1 | mouse                0.092    0.038   2.449  0.014  0.018  0.166
# Group Var                0.005    0.021
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# 2it [00:00,  7.32it/s]
# 2it [00:14, 14.09it/s]
# 3it [00:14,  6.14s/it]
# Log_power~stim
#            sum_sq   df     F  PR(>F)
# stim        0.02  1.0  1.43    0.28
# Residual    0.09  6.0   NaN     NaN
# Using formula Log_power ~  C(stim, Treatment) + (1 | mouse)
#                          Coef. Std.Err.       z  P>|z| [0.025 0.975]
# Intercept                1.926    0.078  24.671  0.000  1.773  2.079
# C(stim, Treatment)[T.1]  0.106    0.035   3.071  0.002  0.038  0.174
# 1 | mouse                0.097    0.034   2.835  0.005  0.030  0.163
# Group Var                0.003    0.013
# n(Divergences) = 1
# 0it [00:00, ?it/s]
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2200: ConvergenceWarning: Retrying MixedLM optimization with lbfgs
#   warnings.warn(
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# 2it [00:00,  6.83it/s]
# 0it [00:00, ?it/s]/home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# 2it [00:00, 13.37it/s]
# 2021-11-25 02:40:19.795285: E external/org_tensorflow/tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_COMPAT_NOT_SUPPORTED_ON_DEVICE: forward compatibility was attempted on non supported HW
# 2021-11-25 02:40:19.795566: E external/org_tensorflow/tensorflow/stream_executor/cuda/cuda_diagnostics.cc:313] kernel version 450.142.0 does not match DSO version 450.156.0 -- cannot find working devices in this configuration
# 2it [00:20, 15.09it/s]
# Log_power~stim
#            sum_sq   df     F  PR(>F)
# stim        0.02  1.0  0.89    0.38
# Residual    0.16  6.0   NaN     NaN
# Using formula Log_power ~  C(stim, Treatment) + (1 | mouse)
#                          Coef. Std.Err.       z  P>|z| [0.025 0.975]
# Intercept                1.855    0.098  18.856  0.000  1.662  2.048
# C(stim, Treatment)[T.1]  0.110    0.032   3.476  0.001  0.048  0.171
# 1 | mouse                0.124    0.043   2.867  0.004  0.039  0.210
# Group Var                0.007    0.023
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# 2it [00:00,  8.35it/s]
# 3it [00:18,  7.81s/it]
# 0it [00:00, ?it/s]
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# 2it [00:00,  9.13it/s]2021-11-25 02:40:23.075262: E external/org_tensorflow/tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_COMPAT_NOT_SUPPORTED_ON_DEVICE: forward compatibility was attempted on non supported HW
# 2021-11-25 02:40:23.075614: E external/org_tensorflow/tensorflow/stream_executor/cuda/cuda_diagnostics.cc:313] kernel version 450.142.0 does not match DSO version 450.156.0 -- cannot find working devices in this configuration
# 3it [00:32, 13.66s/it]
# 0it [00:00, ?it/s]
# Log_power~stim
#            sum_sq   df     F  PR(>F)
# stim        0.00  1.0  0.02    0.88
# Residual    0.17  6.0   NaN     NaN
# Using formula Log_power ~  C(stim, Treatment) + (1 | mouse)
#                          Coef. Std.Err.       z  P>|z|  [0.025 0.975]
# Intercept                1.894    0.119  15.854  0.000   1.660  2.128
# C(stim, Treatment)[T.1]  0.019    0.051   0.366  0.714  -0.082  0.119
# 1 | mouse                0.126    0.052   2.423  0.015   0.024  0.229
# Group Var                0.008    0.030
# n(Divergences) = 1
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# 2it [00:00, 11.15it/s]2021-11-25 02:40:25.878648: E external/org_tensorflow/tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_COMPAT_NOT_SUPPORTED_ON_DEVICE: forward compatibility was attempted on non supported HW
# 2021-11-25 02:40:25.878935: E external/org_tensorflow/tensorflow/stream_executor/cuda/cuda_diagnostics.cc:313] kernel version 450.142.0 does not match DSO version 450.156.0 -- cannot find working devices in this configuration
# 4it [00:29,  7.40s/it]
# 3it [00:35, 14.87s/it]
# 3it [00:18,  8.59s/it]
# 3it [00:17,  7.35s/it]
# 3it [00:39, 16.38s/it]
# 4it [00:30,  7.74s/it]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# Log_power~stim
#            sum_sq   df     F  PR(>F)
# stim        0.02  1.0  0.54    0.49
# Residual    0.20  6.0   NaN     NaN
# Using formula Log_power ~  C(stim, Treatment) + (1 | mouse)
#                          Coef. Std.Err.       z  P>|z|  [0.025 0.975]
# Intercept                1.872    0.114  16.414  0.000   1.649  2.096
# C(stim, Treatment)[T.1]  0.096    0.054   1.785  0.074  -0.009  0.201
# 1 | mouse                0.137    0.050   2.765  0.006   0.040  0.234
# Group Var                0.007    0.026
# n(Divergences) = 1
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# 2it [00:00,  9.34it/s]2021-11-25 02:40:39.571369: E external/org_tensorflow/tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_COMPAT_NOT_SUPPORTED_ON_DEVICE: forward compatibility was attempted on non supported HW
# 2021-11-25 02:40:39.571665: E external/org_tensorflow/tensorflow/stream_executor/cuda/cuda_diagnostics.cc:313] kernel version 450.142.0 does not match DSO version 450.156.0 -- cannot find working devices in this configuration
# 2it [00:20, 13.37it/s]/home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# 2it [00:00, 10.35it/s]
# 4it [00:45, 11.44s/it]
# 3it [00:21,  8.83s/it]
# 4it [00:26,  6.56s/it]
# Log_power~stim
#            sum_sq   df     F  PR(>F)
# stim        0.05  1.0  1.94    0.21
# Residual    0.15  6.0   NaN     NaN
# Using formula Log_power ~  C(stim, Treatment) + (1 | mouse)
#                          Coef. Std.Err.       z  P>|z| [0.025 0.975]
# Intercept                1.809    0.048  37.676  0.000  1.715  1.903
# C(stim, Treatment)[T.1]  0.155    0.039   3.998  0.000  0.079  0.230
# 1 | mouse                0.131    0.020   6.675  0.000  0.093  0.170
# Group Var                0.000    0.005
# 4it [00:49, 12.32s/it]
# 0it [00:00, ?it/s]
# Log_power~stim
#            sum_sq   df     F  PR(>F)
# stim        0.04  1.0  2.78    0.15
# Residual    0.09  6.0   NaN     NaN
# Using formula Log_power ~  C(stim, Treatment) + (1 | mouse)
#                          Coef. Std.Err.       z  P>|z| [0.025 0.975]
# Intercept                1.901    0.089  21.431  0.000  1.728  2.075
# C(stim, Treatment)[T.1]  0.143    0.028   5.097  0.000  0.088  0.197
# 1 | mouse                0.087    0.039   2.226  0.026  0.010  0.164
# Group Var                0.005    0.019
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2200: ConvergenceWarning: Retrying MixedLM optimization with lbfgs
#   warnings.warn(
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2200: ConvergenceWarning: Retrying MixedLM optimization with cg
#   warnings.warn(
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/base/model.py:566: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 0.121597
#   warnings.warn(msg, ConvergenceWarning)
# /home/m/env_jb1/lib/python3.8/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# 2it [00:00,  5.38it/s]
# 2it [00:20, 11.15it/s]
# 4it [00:27,  6.90s/it]
# 3it [00:24, 10.30s/it]
# 3it [00:23,  9.97s/it]
# 4it [00:30,  7.52s/it]
# 4it [00:33,  8.39s/it]
# 4it [00:33,  8.31s/it]
# 3it [00:36, 15.34s/it]
# 3it [00:33, 13.94s/it]
# 4it [00:45, 11.46s/it]
# 4it [00:46, 11.63s/it]
# 4it [00:42, 10.61s/it]

# %%
model_comparison.plot_confusion(
    model_comparison.make_confusion_matrix(reslog, ('method', 'y', 'randomness', 'n_trials')
                                           )).properties(width=140).facet(row='method', column='n_trials')
# NBVAL_SKIP
# Out:
# alt.FacetChart(...)
# Log_power~stim
#            sum_sq   df     F  PR(>F)
# stim        0.07  1.0  6.72    0.04
# Residual    0.06  6.0   NaN     NaN
# Using formula Log_power ~  C(stim, Treatment) + (1 | mouse)
#                          Coef. Std.Err.       z  P>|z| [0.025 0.975]
# Intercept                1.942    0.074  26.088  0.000  1.796  2.088
# C(stim, Treatment)[T.1]  0.188    0.030   6.358  0.000  0.130  0.246
# 1 | mouse                0.068    0.033   2.074  0.038  0.004  0.132
# Group Var                0.003    0.012

# %%
df = model_comparison.make_roc_auc(reslog, binary=False, groups=('method', 'y', 'n_trials'))

bars, roc = model_comparison.plot_roc(df)
bars.facet(column='n_trials', row='y').properties().display()
roc.facet(column='n_trials', row='y').properties()
# NBVAL_SKIP
# Out:
# alt.FacetChart(...)
# alt.FacetChart(...)
