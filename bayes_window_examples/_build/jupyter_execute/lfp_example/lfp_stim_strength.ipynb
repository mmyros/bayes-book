# %% [markdown]
# # LFP example with stim strength

# %%
import numpy as np
import pandas as pd
from bayes_window import BayesWindow, BayesRegression
from bayes_window.generative_models import generate_fake_lfp

# %% [markdown]
# ## ISI

# %%
df = []
for slope in np.linspace(4, 40, 4):
    df1 = generate_fake_lfp(mouse_response_slope=slope)[0]
    df1['stim_strength'] = slope
    df.append(df1)
df = pd.concat(df)

BayesWindow(df=df, y='isi', treatment='stim_strength', group='mouse', detail='i_trial').data_box_detail()
# Out:
# alt.LayerChart(...)

# %%
window = BayesRegression(df=df, y='isi', treatment='stim_strength', group='mouse', detail='i_trial')
window.fit(add_group_slope=False, dist_y='gamma')
window.chart
# Out:
# 2021-12-03 15:20:15.635092: E external/org_tensorflow/tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_COMPAT_NOT_SUPPORTED_ON_DEVICE: forward compatibility was attempted on non supported HW
# 2021-12-03 15:20:15.635256: E external/org_tensorflow/tensorflow/stream_executor/cuda/cuda_diagnostics.cc:313] kernel version 450.142.0 does not match DSO version 450.156.0 -- cannot find working devices in this configuration
# changing x to :Q
# alt.LayerChart(...)

# %%
window.explore_model_kinds()
# Out:
# 2021-12-03 15:20:50.462019: E external/org_tensorflow/tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_COMPAT_NOT_SUPPORTED_ON_DEVICE: forward compatibility was attempted on non supported HW
# 2021-12-03 15:20:50.462214: E external/org_tensorflow/tensorflow/stream_executor/cuda/cuda_diagnostics.cc:313] kernel version 450.142.0 does not match DSO version 450.156.0 -- cannot find working devices in this configuration
# 2021-12-03 15:20:50.469861: E external/org_tensorflow/tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_COMPAT_NOT_SUPPORTED_ON_DEVICE: forward compatibility was attempted on non supported HW
# 2021-12-03 15:20:50.470023: E external/org_tensorflow/tensorflow/stream_executor/cuda/cuda_diagnostics.cc:313] kernel version 450.142.0 does not match DSO version 450.156.0 -- cannot find working devices in this configuration
# 2021-12-03 15:20:50.495293: E external/org_tensorflow/tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_COMPAT_NOT_SUPPORTED_ON_DEVICE: forward compatibility was attempted on non supported HW
# 2021-12-03 15:20:50.495422: E external/org_tensorflow/tensorflow/stream_executor/cuda/cuda_diagnostics.cc:313] kernel version 450.142.0 does not match DSO version 450.156.0 -- cannot find working devices in this configuration
# 2021-12-03 15:20:50.498485: E external/org_tensorflow/tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_COMPAT_NOT_SUPPORTED_ON_DEVICE: forward compatibility was attempted on non supported HW
# 2021-12-03 15:20:50.498572: E external/org_tensorflow/tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_COMPAT_NOT_SUPPORTED_ON_DEVICE: forward compatibility was attempted on non supported HW
# 2021-12-03 15:20:50.498763: E external/org_tensorflow/tensorflow/stream_executor/cuda/cuda_diagnostics.cc:313] kernel version 450.142.0 does not match DSO version 450.156.0 -- cannot find working devices in this configuration
# 2021-12-03 15:20:50.498766: E external/org_tensorflow/tensorflow/stream_executor/cuda/cuda_diagnostics.cc:313] kernel version 450.142.0 does not match DSO version 450.156.0 -- cannot find working devices in this configuration
# 2021-12-03 15:20:50.509180: E external/org_tensorflow/tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_COMPAT_NOT_SUPPORTED_ON_DEVICE: forward compatibility was attempted on non supported HW
# 2021-12-03 15:20:50.509419: E external/org_tensorflow/tensorflow/stream_executor/cuda/cuda_diagnostics.cc:313] kernel version 450.142.0 does not match DSO version 450.156.0 -- cannot find working devices in this configuration
#                            rank         loo     p_loo       d_loo  \
# full                          0  964.235988  9.591452    0.000000
# with_group_slope              1  963.428515  9.746375    0.807473
# no_condition_or_treatment     2  867.059766  1.980286   97.176222
# no-treatment                  3  865.429006  2.003926   98.806982
# no_condition                  4  629.059993  1.395802  335.175995
# no_group                      5  616.613298  1.191146  347.622689
#
#                                  weight         se        dse  warning  \
# full                       4.931156e-01  13.146370   0.000000    False
# with_group_slope           5.068845e-01  13.667829  19.407068    False
# no_condition_or_treatment  9.106496e-09  12.347644  17.134822    False
# no-treatment               1.000505e-08  12.088199  18.150598    False
# no_condition               0.000000e+00  12.182454  17.692761    False
# no_group                   0.000000e+00  11.606323  16.709120    False
#
#                           loo_scale
# full                            log
# with_group_slope                log
# no_condition_or_treatment       log
# no-treatment                    log
# no_condition                    log
# no_group                        log

# %%
## Power

# %% [markdown]
# ## Power

# %%
df = []
for slope in np.linspace(4, 400, 4):
    df1 = generate_fake_lfp(mouse_response_slope=slope)[0]
    df1['stim_strength'] = slope
    df.append(df1)
df = pd.concat(df)

BayesWindow(df=df, y='Power', treatment='stim_strength', group='mouse', detail='i_trial').data_box_detail()
# Out:
# alt.LayerChart(...)

# %%
window = BayesRegression(df=df, y='Power', treatment='stim_strength', group='mouse', detail='i_trial')
window.fit(add_group_slope=False, dist_y='gamma')
window.chart
# Out:
# changing x to :Q
# alt.LayerChart(...)

# %%
window = BayesRegression(df=df, y='Power', treatment='stim_strength', condition='mouse', detail='i_trial')
window.fit(add_condition_slope=True, center_intercept=True, dist_y='gamma')
window.chart
# Out:
# alt.LayerChart(...)

# %%
window.explore_model_kinds()
# Out:
#                            rank           loo        p_loo         d_loo  \
# no_condition_or_treatment     0 -13327.033207   360.461452      0.000000
# no_condition                  1 -33964.037942   844.111832  20637.004735
# full                          2 -55040.696115   959.016818  41713.662909
# no-treatment                  3 -55265.574341  1017.712028  41938.541134
# no_group                      4 -62869.648034   996.921942  49542.614827
#
#                              weight            se           dse  warning  \
# no_condition_or_treatment  0.021243   3936.038596      0.000000     True
# no_condition               0.300426  29238.210530  29537.435422     True
# full                       0.339265  51080.735519  51262.693192     True
# no-treatment               0.091421  51126.642440  51310.881808    False
# no_group                   0.247645  46605.732197  46810.088895     True
#
#                           loo_scale
# no_condition_or_treatment       log
# no_condition                    log
# full                            log
# no-treatment                    log
# no_group                        log

# %%
window.explore_models()
# Out:
# 2021-12-03 15:22:35.228818: E external/org_tensorflow/tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_COMPAT_NOT_SUPPORTED_ON_DEVICE: forward compatibility was attempted on non supported HW
# 2021-12-03 15:22:35.229098: E external/org_tensorflow/tensorflow/stream_executor/cuda/cuda_diagnostics.cc:313] kernel version 450.142.0 does not match DSO version 450.156.0 -- cannot find working devices in this configuration
# 2021-12-03 15:22:35.279745: E external/org_tensorflow/tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_COMPAT_NOT_SUPPORTED_ON_DEVICE: forward compatibility was attempted on non supported HW
# 2021-12-03 15:22:35.280902: E external/org_tensorflow/tensorflow/stream_executor/cuda/cuda_diagnostics.cc:313] kernel version 450.142.0 does not match DSO version 450.156.0 -- cannot find working devices in this configuration
# 2021-12-03 15:22:35.351690: E external/org_tensorflow/tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_COMPAT_NOT_SUPPORTED_ON_DEVICE: forward compatibility was attempted on non supported HW
# 2021-12-03 15:22:35.351989: E external/org_tensorflow/tensorflow/stream_executor/cuda/cuda_diagnostics.cc:313] kernel version 450.142.0 does not match DSO version 450.156.0 -- cannot find working devices in this configuration
# 2021-12-03 15:22:35.388348: E external/org_tensorflow/tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_COMPAT_NOT_SUPPORTED_ON_DEVICE: forward compatibility was attempted on non supported HW
# 2021-12-03 15:22:35.388580: E external/org_tensorflow/tensorflow/stream_executor/cuda/cuda_diagnostics.cc:313] kernel version 450.142.0 does not match DSO version 450.156.0 -- cannot find working devices in this configuration
# 2021-12-03 15:22:35.425032: E external/org_tensorflow/tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_COMPAT_NOT_SUPPORTED_ON_DEVICE: forward compatibility was attempted on non supported HW
# 2021-12-03 15:22:35.425363: E external/org_tensorflow/tensorflow/stream_executor/cuda/cuda_diagnostics.cc:313] kernel version 450.142.0 does not match DSO version 450.156.0 -- cannot find working devices in this configuration
# 2021-12-03 15:22:35.433666: E external/org_tensorflow/tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_COMPAT_NOT_SUPPORTED_ON_DEVICE: forward compatibility was attempted on non supported HW
# 2021-12-03 15:22:35.433923: E external/org_tensorflow/tensorflow/stream_executor/cuda/cuda_diagnostics.cc:313] kernel version 450.142.0 does not match DSO version 450.156.0 -- cannot find working devices in this configuration
# 2021-12-03 15:22:35.443036: E external/org_tensorflow/tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_COMPAT_NOT_SUPPORTED_ON_DEVICE: forward compatibility was attempted on non supported HW
# 2021-12-03 15:22:35.443336: E external/org_tensorflow/tensorflow/stream_executor/cuda/cuda_diagnostics.cc:313] kernel version 450.142.0 does not match DSO version 450.156.0 -- cannot find working devices in this configuration
# 2021-12-03 15:22:35.443725: E external/org_tensorflow/tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_COMPAT_NOT_SUPPORTED_ON_DEVICE: forward compatibility was attempted on non supported HW
# 2021-12-03 15:22:35.443965: E external/org_tensorflow/tensorflow/stream_executor/cuda/cuda_diagnostics.cc:313] kernel version 450.142.0 does not match DSO version 450.156.0 -- cannot find working devices in this configuration
# 2021-12-03 15:22:35.452702: E external/org_tensorflow/tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_COMPAT_NOT_SUPPORTED_ON_DEVICE: forward compatibility was attempted on non supported HW
# 2021-12-03 15:22:35.453028: E external/org_tensorflow/tensorflow/stream_executor/cuda/cuda_diagnostics.cc:313] kernel version 450.142.0 does not match DSO version 450.156.0 -- cannot find working devices in this configuration
#                            rank           loo        p_loo         d_loo  \
# full_normal                   0 -12909.964321   306.893979      0.000000
# full_gamma                    1 -33721.409720   896.827772  20811.445399
# no_condition                  2 -33941.981495   830.375876  21032.017174
# full_student                  3 -34426.502044   866.129476  21516.537723
# full_exponential              4 -34478.170305   715.642326  21568.205984
# no-treatment                  5 -34495.606695   773.636528  21585.642374
# no_condition_or_treatment     6 -54894.679545  1072.489826  41984.715224
# no_group                      7 -62920.564281  1185.501278  50010.599960
# full_lognormal                8 -63107.561343  1047.215306  50197.597022
#
#                                  weight            se           dse  warning  \
# full_normal                2.540261e-01   3768.891001      0.000000     True
# full_gamma                 2.192768e-01  29594.994565  29868.856716    False
# no_condition               1.910885e-01  29290.349382  29565.036192     True
# full_student               1.721911e-01  28851.706504  29125.573937     True
# full_exponential           1.317660e-01  28650.831635  28909.043505     True
# no-treatment               1.016605e-02  29455.759567  29730.468130     True
# no_condition_or_treatment  8.956625e-11  51480.336080  51644.761369    False
# no_group                   5.785791e-03  46756.788123  46950.574170     True
# full_lognormal             1.569973e-02  46484.729860  46679.922218     True
#
#                           loo_scale
# full_normal                     log
# full_gamma                      log
# no_condition                    log
# full_student                    log
# full_exponential                log
# no-treatment                    log
# no_condition_or_treatment       log
# no_group                        log
# full_lognormal                  log

# %%
window.explore_models()
# Out:
#                            rank           loo        p_loo         d_loo  \
# no-treatment                  0  -9702.877468   204.054522      0.000000
# full_normal                   1 -34577.793390   830.623703  24874.915922
# full_exponential              2 -54776.661468   981.788044  45073.783999
# no_condition                  3 -54942.466673  1032.001744  45239.589205
# no_group                      4 -55031.882454  1063.124232  45329.004986
# full_lognormal                5 -55099.414763  1072.977411  45396.537295
# full_student                  6 -55158.066972  1126.830187  45455.189504
# no_condition_or_treatment     7 -55294.488885  1135.027774  45591.611417
# full_gamma                    8 -63188.806888  1144.708836  53485.929420
#
#                                  weight            se           dse  warning  \
# no-treatment               0.000000e+00   2848.766840      0.000000     True
# full_normal                1.885677e-01  28617.967651  28780.365530     True
# full_exponential           2.168212e-01  51436.137549  51532.556126    False
# no_condition               1.886300e-01  51381.584979  51477.850236     True
# no_group                   1.386119e-01  51179.465710  51278.461749     True
# full_lognormal             1.044608e-01  51046.145001  51144.564825     True
# full_student               1.629085e-01  51066.206611  51164.713055     True
# no_condition_or_treatment  1.001047e-11  51107.264189  51204.107253     True
# full_gamma                 0.000000e+00  46279.454191  46389.516528     True
#
#                           loo_scale
# no-treatment                    log
# full_normal                     log
# full_exponential                log
# no_condition                    log
# no_group                        log
# full_lognormal                  log
# full_student                    log
# no_condition_or_treatment       log
# full_gamma                      log

# %%
window.explore_models()
# Out:
#                            rank           loo        p_loo         d_loo  \
# no-treatment                  0 -12188.565524   277.628458      0.000000
# no_group                      1 -12214.599147   294.808174     26.033623
# full_gamma                    2 -12499.036422   323.490812    310.470898
# no_condition_or_treatment     3 -33901.229410   825.574905  21712.663886
# full_student                  4 -34509.759886   849.251714  22321.194362
# full_exponential              5 -54954.136566  1047.199169  42765.571042
# no_condition                  6 -55198.160970   995.027656  43009.595446
# full_lognormal                7 -55473.386044  1071.128870  43284.820519
# full_normal                   8 -62722.549767  1057.673777  50533.984243
#
#                                  weight            se           dse  warning  \
# no-treatment               1.137210e-10   3982.389882      0.000000     True
# no_group                   2.413342e-01   3801.603931   5547.842373     True
# full_gamma                 2.747986e-01   3902.619650   5622.261753     True
# no_condition_or_treatment  9.978563e-11  30030.422069  28737.648985    False
# full_student               1.742881e-01  28816.376088  29124.710743     True
# full_exponential           1.305028e-01  51289.611509  51470.186141    False
# no_condition               1.046156e-01  51087.754555  51271.188830     True
# full_lognormal             7.446068e-02  50851.777550  51034.591638     True
# full_normal                0.000000e+00  46805.738974  47004.072909     True
#
#                           loo_scale
# no-treatment                    log
# no_group                        log
# full_gamma                      log
# no_condition_or_treatment       log
# full_student                    log
# full_exponential                log
# no_condition                    log
# full_lognormal                  log
# full_normal                     log
